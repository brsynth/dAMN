# %% [markdown]
# This version is a reactoring, weight for losses, introduction of loss on V < 0

# %% [markdown]
# ## Utilities

# %%
import cobra
import numpy as np
import pandas as pd
import tensorflow as tf
from typing import List, Tuple, Dict
import matplotlib.pyplot as plt
import os
import json
# Conversion factor from OD to biomass (gDW/L)
ALPHA = 0.37

###############################################################################
# GENERAL UTILITIES
###############################################################################

def area_between_curves(x, f, g):
    """
    Compute the area between two curves f(x) and g(x) using linear interpolation.
    
    Parameters:
        x: List or array of x-values (assumed sorted).
        f: List or array of f(x) values.
        g: List or array of g(x) values.
    
    Returns:
        Total area between the curves.
    """
    area = 0.0
    for i in range(len(x) - 1):
        # Linear interpolation slopes
        slope_f = (f[i+1] - f[i]) / (x[i+1] - x[i])
        slope_g = (g[i+1] - g[i]) / (x[i+1] - x[i])
        
        # Check for intersection within the interval
        if slope_f != slope_g:  # Avoid division by zero
            x_c = x[i] + (g[i] - f[i]) / (slope_f - slope_g)
            if x[i] < x_c < x[i+1]:  # Intersection lies within the interval
                # Compute areas for [x_i, x_c] and [x_c, x_{i+1}]
                f_c = f[i] + slope_f * (x_c - x[i])
                g_c = g[i] + slope_g * (x_c - x[i])
                area += 0.5 * abs(f[i] - g[i]) * (x_c - x[i])  # Area for [x_i, x_c]
                area += 0.5 * abs(f[i+1] - g[i+1]) * (x[i+1] - x_c)  # Area for [x_c, x_{i+1}]
                continue
        
        # No intersection, compute area directly
        diff1 = abs(f[i] - g[i])
        diff2 = abs(f[i+1] - g[i+1])
        area += 0.5 * (diff1 + diff2) * (x[i+1] - x[i])
    
    return area

def compute_curve_similarity(times, ref_OD, pred_OD):
    # Compute area btw the curves ref_OD and pred_OD
    curve_area = area_between_curves(times, ref_OD, pred_OD)    
    # Define the bounding box area
    x_min, x_max = np.min(times), np.max(times)
    y_min = min(np.min(pred_OD), np.min(ref_OD))
    y_max = max(np.max(pred_OD), np.max(ref_OD))
    total_area = (x_max - x_min) * (y_max - y_min)
    similarity = 1 - curve_area / total_area if total_area > 0 else 0
    return similarity

def ReLU(x):
    return x * (x > 0)

###############################################################################
# PLOTTING UTILS
###############################################################################

def plot_losses(title, loss_conc, loss_SV, num_epochs):
    fig, ax1 = plt.subplots(figsize=(8, 5))

    # Primary Y-axis (left) for Loss_conc
    ax1.set_xlabel('Epoch')
    ax1.set_ylabel('Log(Loss conc)', color='blue')
    ax1.plot(range(1, len(loss_conc) + 1), loss_conc, label='Loss conc', color='blue')
    ax1.set_yscale('log')
    ax1.tick_params(axis='y', labelcolor='blue')

    # Create secondary Y-axis (right) for Loss_SV
    ax2 = ax1.twinx()
    ax2.set_ylabel('Log(Loss SV)', color='red')
    ax2.plot(range(1, len(loss_SV) + 1), loss_SV, label='Loss SV', color='red', linestyle='dashed')
    ax2.set_yscale('log')
    ax2.tick_params(axis='y', labelcolor='red')

    # Title and grid
    plt.title(f'Loss conc & Loss SV over {num_epochs} Epochs for {title}')
    ax1.grid(True)

    # Legends
    fig.legend(loc='upper right', bbox_to_anchor=(0.85, 0.85))
    
    plt.show()

def plot_pred(title, times, ref_OD, pred_OD, ref_std=None, pred_std=None):
    similarity = compute_curve_similarity(times, ref_OD, pred_OD)
    
    plt.figure(figsize=(8, 5))
    
    # Plot the reference and predicted OD curves
    plt.plot(times, ref_OD, 'o-', label='Reference OD', color='blue')
    plt.plot(times, pred_OD, 's--', label='Predicted OD', color='red')
    
    # Plot shaded regions for standard deviations if provided
    if ref_std is not None:
        plt.fill_between(times, np.array(ref_OD) - np.array(ref_std), 
                         np.array(ref_OD) + np.array(ref_std), color='blue', alpha=0.2)
    
    if pred_std is not None:
        plt.fill_between(times, np.array(pred_OD) - np.array(pred_std), 
                         np.array(pred_OD) + np.array(pred_std), color='red', alpha=0.2)
    
    plt.xlabel('Time')
    plt.ylabel('OD')
    plt.title(title)
    plt.legend()
    plt.grid(True)
    plt.show()
    
    return similarity

# %% [markdown]
# ## Load data

# %%
###############################################################################
# PROCESS DATA: MEDIA, OD, AND COBRA MODEL
###############################################################################

def build_Stoichiometry_and_Transport_from_cobra(
    cobra_model_file: str, 
    medium_met_ids: List[str], 
    biomass_rxn_id: str,
    verbose=False
) -> Tuple[np.ndarray, np.ndarray, int, int, List[str]]:
    """
    Build stoichiometric and Transport matrices from a COBRA model.
    """
    model = cobra.io.read_sbml_model(cobra_model_file)
    
    # Get reaction and metabolite IDs (strings)
    rxn_ids = [rxn.id for rxn in model.reactions]
    full_met_ids = [met.id for met in model.metabolites]

    m = len(full_met_ids)
    n = len(rxn_ids)

    # Build stoichiometric matrix
    Stoichiometry = np.zeros((m, n), dtype=np.float32)
    for j, rxn in enumerate(model.reactions):
        for met, coeff in rxn.metabolites.items():
            i = full_met_ids.index(met.id)
            Stoichiometry[i, j] = coeff
            
    # Build Transport matrix
    Transport = np.zeros((len(medium_met_ids), n), dtype=np.float32)
    for col_idx, rxn_obj in enumerate(model.reactions):
        rxn_id = rxn_obj.id
        if rxn_id == biomass_rxn_id:
            row_idx = medium_met_ids.index('BIOMASS')
            Transport[row_idx, col_idx] = 1.0
            if verbose:
                print(f'Transport[{row_idx},{col_idx}] = 1.0  BIOMASS')
        elif rxn_id.startswith('EX_'):
            io = rxn_id[-1:]
            met_id_candidate = rxn_id[3:-2]  # e.g. 'EX_glc__D_e' -> 'glc__D_'
            if met_id_candidate in medium_met_ids:
                row_idx = medium_met_ids.index(met_id_candidate)
                Transport[row_idx, col_idx] = -1.0 if io == 'i' else 1.0 
                if verbose:
                    print(f'Transport[{row_idx},{col_idx}] = {Transport[row_idx, col_idx]}  {rxn_id}')

    if verbose:
        print(f'Transport shape: {Transport.shape}, Stoichiometry shape: {Stoichiometry.shape}')
        print(f'Number of metabolites (k): {len(medium_met_ids)}, Number of fluxes (n): {n}')
    return Stoichiometry, Transport, m, n, rxn_ids

def process_data(
    media_file: str,
    od_file: str,
    cobra_model_file: str,
    biomass_rxn_id: str,
    verbose=False
) -> Tuple[np.ndarray, List[str], Dict[int, np.ndarray], np.ndarray, np.ndarray, List[str]]:
    """
    Process media, OD, and COBRA model to generate structured experimental data and matrices.
    """
    media_df = pd.read_csv(media_file)
    od_df = pd.read_csv(od_file)

    # Extract time points from columns like 'T_...'
    times = sorted(pd.unique(od_df.filter(like='T').values.flatten()))
    times = [t for t in times if not pd.isnull(t)]

    # Use all media metabolites (skip the first column 'ID') and add BIOMASS at the end.
    metabolite_ids = list(media_df.columns[1:])
    metabolite_ids.append('BIOMASS')
    
    experiment_data = {}
    for exp_id in media_df['ID']:
        t_col = f'T_{int(exp_id)}'
        od_col = f'OD_{int(exp_id)}'

        if t_col not in od_df.columns or od_col not in od_df.columns:
            raise ValueError(f'Missing columns for experiment ID {exp_id} in OD file.')

        od_times = od_df[t_col].values
        log_od_values = od_df[od_col].values

        od_values = np.exp(log_od_values)
        biomass_concentration = ALPHA * od_values  # resulting in gDW/L

        conc_matrix = np.full((len(times), len(metabolite_ids)), np.nan, dtype=np.float32)
        # Set initial media concentrations (excluding biomass)
        row_in_media = media_df[media_df['ID'] == exp_id].iloc[0, 1:].values
        conc_matrix[0, :-1] = row_in_media

        # Set initial biomass from OD data if available
        if 0 in od_times:
            idx_0 = np.where(od_times == 0)[0][0]
            conc_matrix[0, -1] = biomass_concentration[idx_0]
        else:
            conc_matrix[0, -1] = biomass_concentration[0]

        # Fill in biomass for subsequent time points
        for i_time, t_val in enumerate(times[1:], start=1):
            if t_val in od_times:
                idx_t = np.where(od_times == t_val)[0][0]
                conc_matrix[i_time, -1] = biomass_concentration[idx_t]

        experiment_data[int(exp_id)] = conc_matrix

    # Build stoichiometric and transport matrices
    Stoichiometry, Transport, _, _, rxn_ids = build_Stoichiometry_and_Transport_from_cobra(
        cobra_model_file, metabolite_ids, biomass_rxn_id, verbose=verbose
    )

    return np.array(times), metabolite_ids, experiment_data, Stoichiometry, Transport, rxn_ids

def prepare_experiment_array(
    times: np.ndarray,
    metabolite_ids: List[str],
    experiment_data: Dict[int, np.ndarray]
) -> np.ndarray:
    """
    Flatten experimental data into a 2D array with shape: (num_experiments, (T+1)*k).
    """
    T_plus_1 = len(times)
    k = len(metabolite_ids)
    all_flat = []
    for exp_id in sorted(experiment_data.keys()):
        conc_matrix = experiment_data[exp_id]
        row_flat = conc_matrix.reshape(-1)
        all_flat.append(row_flat)
    return np.stack(all_flat, axis=0)

# %% [markdown]
# ## Model

# %%
###############################################################################
# MODEL with BATCHED TIME-UNROLL and ACTUAL TIME UPDATES
###############################################################################

from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.models import Model

class FluxNetwork(tf.keras.layers.Layer):
    def __init__(self, input_dim, output_dim, hidden_layers=[100], dropout_rate=0.2, name='flux_network', **kwargs):
        super().__init__(name=name, **kwargs)
        # Use Sequential to ensure Keras tracks all sublayers
        self.hidden_layers = tf.keras.Sequential([
            tf.keras.layers.Dense(
                units=h, 
                activation='relu', 
                name=f'hidden_dense_{i}'
            ) for i, h in enumerate(hidden_layers)
        ], name='hidden_layers')

        self.dropout = tf.keras.layers.Dropout(rate=dropout_rate, name='dropout')
        self.out_layer = tf.keras.layers.Dense(
            units=output_dim, 
            activation='linear', 
            name='output_dense'
        )

    def call(self, x, training=False):
        x = self.hidden_layers(x)
        x = self.dropout(x, training=training)
        return self.out_layer(x)

class MetabolicModel(tf.keras.Model):
    """
    Model that unrolls the time dimension.
    Expects input shape: (batch_size, T+1, k)
    dt_vector: tensor of shape (T,) with time differences (t[i+1]-t[i])
    """
    def __init__(self, times, Transport, Stoichiometry, rxn_ids, biomass_rxn_id, 
                 hidden_layers=[100], dropout_rate=0.2, 
                 loss_weight_ng_v = 5e-1, 
                 loss_weight_drop_conc  = 1e-1,
                 loss_weight_decay_conc = 5e-1,
                 loss_weight_sv = 1e-3,
                 verbose=True, name='metabolic_model'):
        super().__init__(name=name)
        self.times = times
        self.T = len(times) - 1  # T represents the number of intervals
        dt_vector = np.diff(times).astype(np.float32)
        dt_vector = dt_vector / np.min(dt_vector)
        self.dt_vector = tf.convert_to_tensor(dt_vector, dtype=tf.float32)
        self.Transport = Transport
        self.Stoichiometry = Stoichiometry
        self.k, self.n = Transport.shape[0], Transport.shape[1]
        self.rxn_ids = rxn_ids
        self.biomass_rxn_id = biomass_rxn_id
        self.biomass_flux_index = rxn_ids.index(biomass_rxn_id)
        self.hidden_layers = hidden_layers 
        self.dropout_rate = dropout_rate
        
        # weight to compute loss (for sv and concentration)
        self.loss_weight_ng_v = loss_weight_ng_v
        self.loss_weight_sv = loss_weight_sv
        self.loss_weight_drop_conc = loss_weight_drop_conc
        self.loss_weight_decay_conc = loss_weight_decay_conc

        # Initialize FluxNetwork with a fixed name
        self.flux_net = FluxNetwork(self.k, self.n, hidden_layers, dropout_rate, name='flux_network')

    def build(self, input_shape):
        super().build(input_shape)
        # No additional build steps are necessary since all layers are initialized in __init__

    def printout(self):
        print(f'-----------------------------MetabolicModel-----------------------------')
        print(f'times: {self.times[0]:.2f}, {self.times[1]:.2f}, ..., {self.times[-1]:.2f}')
        print(f'T: {self.T}')
        print(f'dt: {self.dt_vector.numpy()}')
        print(f'Transport: {self.Transport.shape}')
        print(f'Stoichiometry: {self.Stoichiometry.shape}')
        print(f'n: {self.n}')
        print(f'k: {self.k}')
        print(f'Reaction ids: {len(self.rxn_ids)}')
        print(f'Biomass id: {self.biomass_rxn_id}')
        print(f'Biomass flux index: {self.biomass_flux_index}')
        print(f'Hidden Layers: {self.hidden_layers}')
        print(f'Dropout Rate: {self.dropout_rate}')
        print(f'------------------------------------------------------------------------')

    def call(self, C_ref_batch, training=False, verbose=False):
        """
        C_ref_batch: shape (batch_size, T+1, k)
        dt_vector: shape (T,) containing dt for each time interval.
        """
        batch_size = tf.shape(C_ref_batch)[0]
        T = tf.shape(C_ref_batch)[1] - 1  # T is number of intervals

        # Initial predictions from time 0.
        C_pred = C_ref_batch[:, 0, :]  # shape: (batch_size, k)
        total_loss_sv = 0.0
        total_loss_conc = 0.0

        for t in tf.range(T):

            # Compute fluxes; shape: (batch_size, n)
            v_t = self.flux_net(C_pred, training=training)

            # Compute change in external concentrations from fluxes; shape: (batch_size, k)
            delta_C_ext = tf.matmul(v_t, self.Transport, transpose_b=True)
            dt = self.dt_vector[t]  # scalar dt for this time interval
            C_next = C_pred + delta_C_ext * dt  # update using actual time difference

            # Reference concentrations for time t+1, shape: (batch_size, k)
            C_ref_next = C_ref_batch[:, t+1, :]

            # Compute concentration prediction loss on observed values
            mask = ~tf.math.is_nan(C_ref_next)
            mse_conc = tf.reduce_mean(tf.square(tf.boolean_mask(C_next, mask) - tf.boolean_mask(C_ref_next, mask)))

            # Compute stoichiometric violation loss (MSE over all metabolites)
            S_v = tf.matmul(v_t, self.Stoichiometry, transpose_b=True)  # shape: (batch_size, m)
            mse_sv = tf.reduce_mean(tf.square(S_v))
            mse_ng_v = tf.reduce_mean(tf.nn.relu(-v_t))
            mse_sv +=  mse_ng_v * self.loss_weight_ng_v
            total_loss_sv += mse_sv * self.loss_weight_sv  
            
            # Add loss to penalize drop in biomass concentration
            mse_drop_conc = tf.reduce_mean(tf.nn.relu(C_pred[:,-1]-C_next[:,-1]))
            loss_weight_drop_conc = tf.exp(-self.loss_weight_decay_conc * tf.cast(t, tf.float32)) 
            mse_conc += mse_drop_conc * loss_weight_drop_conc
        
            # Handling the lag phase !!!
            loss_weight_conc = tf.exp(-self.loss_weight_decay_conc * tf.cast(t, tf.float32)) 
            total_loss_conc += mse_conc * loss_weight_conc

            C_pred = C_next

            if verbose > 1:
                # print for first element in batch
                i = int(verbose)
                flux_biomass = v_t[self.biomass_flux_index]
                tf.print(f'Batch: {i} Time step {t} '
                         f'Glucose: {C_next[i, 0]:.3f} '
                         f'pred: {C_pred[i,-1]:.3f}  flux: {flux_biomass[i]:.3f} '
                         f'next: {C_next[i,-1]:.3f} ref-next: {C_ref_next[i, -1]:.3f} '
                         f'Loss SV: {total_loss_sv:.3f} Loss conc: {total_loss_conc:.3f}')

        return total_loss_sv, total_loss_conc

    def save_model(self, model_name='ODmodel', verbose=False):
        """
        Save the model weights and configuration (architecture parameters) to files.
        """
        weights_path = f'{model_name}.weights.h5'
        config_path = f'{model_name}.config.json'

        # Ensure model is built before saving by running a dummy forward pass
        dummy_input = tf.random.normal((1, len(self.times), self.k))  # Shape: (batch_size, T+1, k)
        _ = self(dummy_input)  # Forces all layers to initialize

        # Save the weights
        self.save_weights(weights_path)

        # Save model configuration
        config = {
        'times': self.times.tolist() if isinstance(self.times, (np.ndarray, list)) else list(self.times),
        'T': int(self.T),
        'Transport': self.Transport.tolist(),
        'Stoichiometry': self.Stoichiometry.tolist(),
        'k': int(self.k),
        'n': int(self.n),
        'rxn_ids': self.rxn_ids,
        'biomass_rxn_id': self.biomass_rxn_id,
        'biomass_flux_index': int(self.biomass_flux_index),
        'hidden_layers': self.hidden_layers,
        'dropout_rate': float(self.dropout_rate)
        }
    
        # Write config to JSON file
        with open(config_path, 'w') as f:
            json.dump(config, f)

        if verbose:
            print(f'Model weights saved to '{weights_path}' and config saved to '{config_path}'.')

    @classmethod
    def load_model(cls, model_name='ODmodel', verbose=False):
        """
        Load a model from saved weights and configuration.
        """
        weights_path = f'{model_name}.weights.h5'
        config_path = f'{model_name}.config.json'

        # Check if files exist
        if not os.path.exists(config_path):
            raise FileNotFoundError(f'Configuration file '{config_path}' not found.')
        if not os.path.exists(weights_path):
            raise FileNotFoundError(f'Weights file '{weights_path}' not found.')

        # Load the configuration
        with open(config_path, 'r') as f:
            config = json.load(f)

        # Extract parameters
        times = config['times']
        Transport = np.array(config['Transport'])
        Stoichiometry = np.array(config['Stoichiometry'])
        rxn_ids = config['rxn_ids']
        biomass_rxn_id = config['biomass_rxn_id']
        hidden_layers = config['hidden_layers']
        dropout_rate = config['dropout_rate']

        # Create a new model instance
        model = cls(
        times=times,
        Transport=Transport,
        Stoichiometry=Stoichiometry,
        rxn_ids=rxn_ids,
        biomass_rxn_id=biomass_rxn_id,
        hidden_layers=hidden_layers,
        dropout_rate=dropout_rate,
        verbose=verbose,
        name='metabolic_model'
        )

        # Ensure the model is built before loading weights
        dummy_input = tf.random.normal((1, len(times), model.k))  # Shape: (batch_size, T+1, k)
        _ = model(dummy_input)  # Forces all layers to initialize

        # Load saved weights
        model.load_weights(weights_path)

        if verbose:
            print(f'Model built from '{config_path}' and weights loaded from '{weights_path}'.')

        return model

# %% [markdown]
# ## Training and evaluating

# %%
###############################################################################
# CREATE TRAIN AND CROSS-VALIDATE MODEL
###############################################################################

def create_model_train_val(
    media_file, od_file,
    cobra_model_file,
    biomass_rxn_id,
    x_fold=5, 
    hidden_layers=[100], dropout_rate=0.2,
    verbose=False
):
    # Load data and model matrices.
    times, metabolite_ids, experiment_data, Stoichiometry, Transport, rxn_ids = process_data(
        media_file, od_file, cobra_model_file, biomass_rxn_id, verbose=verbose
    )
      
    # Split experiments into train and validation sets.
    exp_ids = list(experiment_data.keys())
    np.random.shuffle(exp_ids)
    if x_fold > 1:
        split = int(len(exp_ids) * (1 - 1/x_fold))
        train_ids = exp_ids[:split]
        val_ids = exp_ids[split:]
        val_data = {eid: experiment_data[eid] for eid in val_ids}
        val_array = prepare_experiment_array(times, metabolite_ids, val_data)
    else:
        train_ids = exp_ids
        val_array = None
        
    train_data = {eid: experiment_data[eid] for eid in train_ids}
    train_array = prepare_experiment_array(times, metabolite_ids, train_data)
    
    if verbose:
        print(f'Train shape: {train_array.shape}')
        if val_array is not None:
            print(f'Val shape: {val_array.shape}')

    model = MetabolicModel(times, Transport, Stoichiometry, rxn_ids, biomass_rxn_id, 
            hidden_layers=hidden_layers, dropout_rate=dropout_rate, verbose=verbose)

    return model, train_array, val_array
    
def train_step(model, C_ref_batch, optimizer, verbose=False):
    with tf.GradientTape() as tape:
        loss_sv, loss_conc = model(C_ref_batch, training=True, verbose=verbose)
        loss = loss_sv + loss_conc
    gradients = tape.gradient(loss, model.trainable_variables)
    optimizer.apply_gradients(zip(gradients, model.trainable_variables))
    return loss_sv, loss_conc

def evaluate_model_on_data(model, data_array):
    Z = data_array.shape[0]
    C_all = data_array.reshape((Z, model.T+1, model.k))
    loss_sv, loss_conc = model(C_all, training=False)
    return loss_sv.numpy(), loss_conc.numpy()

def train_model(
    model, 
    train_array, val_array=None,  # shape: (Z, (T+1)*k)
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3),
    num_epochs=10, batch_size=10, patience=10,
    verbose=False
):
    Z = train_array.shape[0]
    C_train_all = train_array.reshape((Z, model.T+1, model.k))
    
    if val_array is not None:
        Z_val = val_array.shape[0]
        C_val_all = val_array.reshape((Z_val, model.T+1, model.k))
    else:
        C_val_all = None

    losses_sv_train, losses_conc_train = [], []
    losses_sv_val, losses_conc_val = [], []

    best_val_loss = np.inf
    best_weights = None
    steps_no_improv = 0
    n_batches = int(np.ceil(Z / batch_size))
    
    for epoch in range(num_epochs):
        # Shuffle experiments at each epoch
        idxs = np.arange(Z)
        np.random.shuffle(idxs)
        C_train_all = C_train_all[idxs]

        epoch_loss_sv, epoch_loss_conc = 0.0, 0.0
        for b in range(n_batches):
            start = b * batch_size
            end = min(start + batch_size, Z)
            C_batch = C_train_all[start:end]  # shape: (batch, T+1, k)
            loss_sv, loss_conc = train_step(model, C_batch, optimizer, verbose=verbose)
            epoch_loss_sv += loss_sv.numpy()
            epoch_loss_conc += loss_conc.numpy()

        epoch_loss_sv /= n_batches
        epoch_loss_conc /= n_batches
        losses_sv_train.append(epoch_loss_sv)
        losses_conc_train.append(epoch_loss_conc)

        if C_val_all is not None:
            val_sv, val_conc = model(C_val_all, training=False) # !!!
            val_sv_np = val_sv.numpy()
            val_conc_np = val_conc.numpy()
            losses_sv_val.append(val_sv_np)
            losses_conc_val.append(val_conc_np)
            val_loss = val_sv_np + val_conc_np
            print(f'[Epoch {epoch+1}/{num_epochs}] Train SV: {epoch_loss_sv:.1e} conc: {epoch_loss_conc:.1e} | '
                  f'Val SV: {val_sv_np:.1e} conc: {val_conc_np:.1e}')
            if val_loss < best_val_loss:
                best_val_loss = val_loss
                best_weights = model.get_weights()
                steps_no_improv = 0
            else:
                steps_no_improv += 1
                if steps_no_improv >= patience:
                    print('Early stopping triggered. Restoring best weights.')
                    model.set_weights(best_weights)
                    break
        else:
            print(f'[Epoch {epoch+1}/{num_epochs}] Train SV: {epoch_loss_sv:.1e} Loss conc: {epoch_loss_conc:.1e}')

    return (losses_sv_train, losses_conc_train), (losses_sv_val, losses_conc_val)

###############################################################################
# PREDICT TIMECOURSE FOR VALIDATION 
###############################################################################

def predict_timecourse(model, C_ref_batch, verbose=False):
    """
    Predict the full timecourse of metabolite concentrations for a batch.
    Input shape: (batch_size, T+1, k)
    Returns: Tensor of shape (batch_size, T+1, k)
    """

    batch_size = tf.shape(C_ref_batch)[0]
    T = tf.shape(C_ref_batch)[1]
    predictions = tf.TensorArray(tf.float32, size=T)
    C_pred = C_ref_batch[:, 0, :]  # (batch_size, T+1, k) -> (batch_size, k) 
    predictions = predictions.write(0, C_pred)
    for t in tf.range(T-1):
        v_t = model.flux_net(C_pred, training=False)
        delta_C_ext = tf.matmul(v_t, model.Transport, transpose_b=True)
        dt = model.dt_vector[t]
        C_next = C_pred + delta_C_ext * dt # TensorShape([56, 29]
        if verbose:
            for i in range(batch_size):
                flux_biomass = v_t[i, model.biomass_flux_index]
                tf.print(f'Batch: {i} Time step {t} Glucose: {C_next[i, 0]:.2f} '
                f'Ref: {C_ref_batch[i, t, -1]:.2f} Pred: {C_pred[i, -1]:.2f} '
                f'Flux: {flux_biomass:.2f} Next: {C_next[i, -1]:.2f}')
        predictions = predictions.write(t+1, C_next)
        C_pred = C_next
    predictions_stacked = predictions.stack()  # shape: (T+1, batch_size, k)
    predictions_stacked = tf.transpose(predictions_stacked, [1, 0, 2])
    return predictions_stacked

def predict_biomass_on_val_data(model, val_array, verbose=False):
    """
    Predict the biomass timecourse for the validation data.
    1. Reshape val_array (Z_val, (T+1)*k) to (Z_val, T+1, k)
    2. Obtain predicted biomass (last column) for each time point.
    
    Returns:
       pred_OD:  OD predictions (Z_val, T+1) as a NumPy array
       ref_OD:   OD reference (Z_val, T+1) as a NumPy array
    """
    Z_val = val_array.shape[0]
    C_val_all = val_array.reshape((Z_val, model.T+1, model.k))
    predictions = predict_timecourse(model, C_val_all, verbose=verbose)
    # Extract biomass column (assumed last column)
    pred_biomass = predictions[:, :, -1]  # shape (Z_val, T+1) -- a tf.Tensor
    ref_biomass = C_val_all[:, :, -1]     # shape (Z_val, T+1) -- a NumPy array
    
    # Convert to OD = biomass / ALPHA
    pred_OD = pred_biomass.numpy() / ALPHA   # still a tf.Tensor
    ref_OD = ref_biomass / ALPHA             # a NumPy array
    return pred_OD, ref_OD

# %% [markdown]
# # Main code

# %%
###############################################################################
# TRAIN
###############################################################################

# Set environment (GPU configuration if needed)
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'
print('Physical GPUs:', tf.config.list_physical_devices('GPU'))

# Update with your actual file names
folder = './'
run_name = 'OD_clean_20_1.0'
media_file = folder+'data/'+'media.csv'                 
od_file = folder+'data/'+run_name+'.csv'               
cobra_model_file = folder+'data/'+'iML1515_duplicated.xml'
biomass_rxn_id = 'BIOMASS_Ec_iML1515_core_75p37M'


# Hyperparameters
hidden_layers = [500]
num_epochs = 1000
x_fold = 5       
batch_size = 10
patience = 50
N_iter = 3

# Split data
model, train_array, val_array = create_model_train_val(
    media_file, od_file,
    cobra_model_file,
    biomass_rxn_id,
    x_fold=x_fold, 
    hidden_layers=hidden_layers, dropout_rate=0.2,
    verbose=False
)

for i in range(N_iter):
    # Train
    lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate=1e-3,
    decay_steps=280,   # tune based on your experiments (280 experiments => one full cycle)
    decay_rate=0.9,
    staircase=True
    )
    (sv_train, conc_train), (sv_val, conc_val) = train_model(
    model, 
    train_array, val_array=val_array,  
    optimizer=tf.keras.optimizers.Adam(learning_rate=lr_schedule),
    num_epochs=num_epochs, batch_size=batch_size, patience=patience,
    verbose=True
    )

    # save model
    model_name = folder+'model/'+run_name+'_'+str(int(i))
    model.save_model(model_name=model_name, verbose=True)

    # Plot training and validation loss curves
    plot_losses('Training', conc_train, sv_train, num_epochs)
    if x_fold > 1:
        plot_losses('Validation', conc_val, sv_val, num_epochs)
# Out:
# Physical GPUs: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# [Epoch 1/1000] Train SV: 5.2e+01 conc: 1.5e+01 | Val SV: 2.2e+00 conc: 1.3e+00
# [Epoch 2/1000] Train SV: 2.0e+00 conc: 2.2e+00 | Val SV: 6.7e-01 conc: 3.8e-01
# [Epoch 3/1000] Train SV: 7.0e-01 conc: 1.5e+00 | Val SV: 2.6e-01 conc: 5.7e-01
# [Epoch 4/1000] Train SV: 4.0e-01 conc: 1.4e+00 | Val SV: 1.6e-01 conc: 4.2e-01
# [Epoch 5/1000] Train SV: 3.0e-01 conc: 1.1e+00 | Val SV: 1.0e-01 conc: 9.0e-02
# [Epoch 6/1000] Train SV: 2.5e-01 conc: 1.4e+00 | Val SV: 7.1e-02 conc: 3.2e-01
# [Epoch 7/1000] Train SV: 2.1e-01 conc: 9.6e-01 | Val SV: 5.8e-02 conc: 3.1e-01
# [Epoch 8/1000] Train SV: 1.9e-01 conc: 1.0e+00 | Val SV: 4.8e-02 conc: 1.6e-01
# [Epoch 9/1000] Train SV: 1.7e-01 conc: 1.1e+00 | Val SV: 4.9e-02 conc: 3.1e-01
# [Epoch 10/1000] Train SV: 1.6e-01 conc: 1.0e+00 | Val SV: 3.9e-02 conc: 9.3e-02
# [Epoch 11/1000] Train SV: 1.5e-01 conc: 9.5e-01 | Val SV: 2.6e-02 conc: 8.1e-02
# [Epoch 12/1000] Train SV: 1.3e-01 conc: 8.6e-01 | Val SV: 2.5e-02 conc: 1.0e-01
# [Epoch 13/1000] Train SV: 1.2e-01 conc: 7.1e-01 | Val SV: 2.2e-02 conc: 1.2e-01
# [Epoch 14/1000] Train SV: 1.0e-01 conc: 8.0e-01 | Val SV: 2.1e-02 conc: 6.8e-02
# [Epoch 15/1000] Train SV: 9.9e-02 conc: 7.6e-01 | Val SV: 2.1e-02 conc: 1.2e-01
# [Epoch 16/1000] Train SV: 9.8e-02 conc: 7.9e-01 | Val SV: 2.0e-02 conc: 3.3e-01
# [Epoch 17/1000] Train SV: 9.4e-02 conc: 7.6e-01 | Val SV: 2.0e-02 conc: 9.3e-02
# [Epoch 18/1000] Train SV: 8.8e-02 conc: 7.4e-01 | Val SV: 1.8e-02 conc: 3.3e-01
# [Epoch 19/1000] Train SV: 8.6e-02 conc: 7.6e-01 | Val SV: 1.4e-02 conc: 8.7e-02
# [Epoch 20/1000] Train SV: 8.0e-02 conc: 6.8e-01 | Val SV: 1.5e-02 conc: 9.8e-02
# [Epoch 21/1000] Train SV: 7.4e-02 conc: 7.1e-01 | Val SV: 1.3e-02 conc: 2.9e-01
# [Epoch 22/1000] Train SV: 7.7e-02 conc: 7.1e-01 | Val SV: 1.4e-02 conc: 9.9e-02
# [Epoch 23/1000] Train SV: 7.3e-02 conc: 6.7e-01 | Val SV: 1.3e-02 conc: 8.9e-02
# [Epoch 24/1000] Train SV: 7.2e-02 conc: 6.5e-01 | Val SV: 1.4e-02 conc: 1.3e-01
# [Epoch 25/1000] Train SV: 6.8e-02 conc: 6.8e-01 | Val SV: 1.3e-02 conc: 2.1e-01
# [Epoch 26/1000] Train SV: 6.6e-02 conc: 6.2e-01 | Val SV: 9.5e-03 conc: 1.0e-01
# [Epoch 27/1000] Train SV: 5.9e-02 conc: 6.0e-01 | Val SV: 9.7e-03 conc: 1.2e-01
# [Epoch 28/1000] Train SV: 6.0e-02 conc: 5.8e-01 | Val SV: 9.9e-03 conc: 4.8e-02
# [Epoch 29/1000] Train SV: 5.8e-02 conc: 4.9e-01 | Val SV: 1.0e-02 conc: 9.5e-02
# [Epoch 30/1000] Train SV: 5.3e-02 conc: 5.2e-01 | Val SV: 1.0e-02 conc: 6.7e-02
# [Epoch 31/1000] Train SV: 5.3e-02 conc: 4.8e-01 | Val SV: 1.0e-02 conc: 5.2e-02
# [Epoch 32/1000] Train SV: 5.5e-02 conc: 4.3e-01 | Val SV: 1.1e-02 conc: 1.4e-01
# [Epoch 33/1000] Train SV: 5.2e-02 conc: 4.7e-01 | Val SV: 7.7e-03 conc: 8.5e-02
# [Epoch 34/1000] Train SV: 5.0e-02 conc: 4.9e-01 | Val SV: 9.0e-03 conc: 2.4e-01
# [Epoch 35/1000] Train SV: 4.5e-02 conc: 5.1e-01 | Val SV: 8.0e-03 conc: 1.6e-01
# [Epoch 36/1000] Train SV: 4.8e-02 conc: 4.1e-01 | Val SV: 8.0e-03 conc: 3.7e-02
# [Epoch 37/1000] Train SV: 4.6e-02 conc: 4.7e-01 | Val SV: 7.7e-03 conc: 5.0e-02
# [Epoch 38/1000] Train SV: 4.5e-02 conc: 4.3e-01 | Val SV: 9.1e-03 conc: 8.6e-02
# [Epoch 39/1000] Train SV: 4.4e-02 conc: 3.7e-01 | Val SV: 7.9e-03 conc: 8.1e-02
# [Epoch 40/1000] Train SV: 4.8e-02 conc: 4.0e-01 | Val SV: 7.6e-03 conc: 4.8e-02
# [Epoch 41/1000] Train SV: 4.3e-02 conc: 4.0e-01 | Val SV: 8.0e-03 conc: 7.1e-02
# [Epoch 42/1000] Train SV: 4.2e-02 conc: 4.1e-01 | Val SV: 6.3e-03 conc: 1.4e-01
# [Epoch 43/1000] Train SV: 4.0e-02 conc: 3.9e-01 | Val SV: 6.5e-03 conc: 4.3e-02
# [Epoch 44/1000] Train SV: 4.1e-02 conc: 3.4e-01 | Val SV: 5.5e-03 conc: 4.3e-02
# [Epoch 45/1000] Train SV: 3.8e-02 conc: 3.2e-01 | Val SV: 6.8e-03 conc: 4.0e-02
# [Epoch 46/1000] Train SV: 3.7e-02 conc: 3.4e-01 | Val SV: 5.7e-03 conc: 3.6e-02
# [Epoch 47/1000] Train SV: 3.5e-02 conc: 3.5e-01 | Val SV: 5.3e-03 conc: 3.9e-02
# [Epoch 48/1000] Train SV: 3.5e-02 conc: 3.5e-01 | Val SV: 5.1e-03 conc: 1.4e-01
# [Epoch 49/1000] Train SV: 3.5e-02 conc: 3.4e-01 | Val SV: 5.2e-03 conc: 5.9e-02
# [Epoch 50/1000] Train SV: 3.3e-02 conc: 2.9e-01 | Val SV: 5.7e-03 conc: 6.0e-02
# [Epoch 51/1000] Train SV: 3.2e-02 conc: 3.0e-01 | Val SV: 5.1e-03 conc: 2.5e-02
# [Epoch 52/1000] Train SV: 3.3e-02 conc: 3.1e-01 | Val SV: 5.3e-03 conc: 7.4e-02
# [Epoch 53/1000] Train SV: 3.3e-02 conc: 3.2e-01 | Val SV: 4.9e-03 conc: 3.3e-02
# [Epoch 54/1000] Train SV: 3.4e-02 conc: 3.2e-01 | Val SV: 4.5e-03 conc: 5.0e-02
# [Epoch 55/1000] Train SV: 3.1e-02 conc: 3.1e-01 | Val SV: 5.7e-03 conc: 5.6e-02
# [Epoch 56/1000] Train SV: 3.1e-02 conc: 3.6e-01 | Val SV: 4.4e-03 conc: 4.7e-02
# [Epoch 57/1000] Train SV: 3.0e-02 conc: 3.0e-01 | Val SV: 4.7e-03 conc: 1.5e-01
# [Epoch 58/1000] Train SV: 2.9e-02 conc: 3.1e-01 | Val SV: 4.9e-03 conc: 5.9e-02
# [Epoch 59/1000] Train SV: 3.0e-02 conc: 3.2e-01 | Val SV: 4.1e-03 conc: 6.4e-02
# [Epoch 60/1000] Train SV: 2.9e-02 conc: 2.8e-01 | Val SV: 4.6e-03 conc: 5.1e-02
# [Epoch 61/1000] Train SV: 3.0e-02 conc: 3.0e-01 | Val SV: 4.8e-03 conc: 8.4e-02
# [Epoch 62/1000] Train SV: 2.8e-02 conc: 2.8e-01 | Val SV: 4.8e-03 conc: 4.3e-02
# [Epoch 63/1000] Train SV: 2.7e-02 conc: 2.3e-01 | Val SV: 3.9e-03 conc: 5.0e-02
# [Epoch 64/1000] Train SV: 2.5e-02 conc: 2.4e-01 | Val SV: 5.2e-03 conc: 7.8e-02
# [Epoch 65/1000] Train SV: 2.8e-02 conc: 2.8e-01 | Val SV: 4.2e-03 conc: 4.0e-02
# [Epoch 66/1000] Train SV: 2.6e-02 conc: 2.2e-01 | Val SV: 4.2e-03 conc: 3.3e-02
# [Epoch 67/1000] Train SV: 3.0e-02 conc: 3.0e-01 | Val SV: 4.1e-03 conc: 2.3e-02
# [Epoch 68/1000] Train SV: 2.7e-02 conc: 2.8e-01 | Val SV: 4.2e-03 conc: 2.0e-02
# [Epoch 69/1000] Train SV: 2.5e-02 conc: 3.0e-01 | Val SV: 3.8e-03 conc: 2.9e-02
# [Epoch 70/1000] Train SV: 2.5e-02 conc: 2.4e-01 | Val SV: 4.1e-03 conc: 5.0e-02
# [Epoch 71/1000] Train SV: 2.7e-02 conc: 2.2e-01 | Val SV: 4.3e-03 conc: 3.6e-02
# [Epoch 72/1000] Train SV: 2.3e-02 conc: 1.9e-01 | Val SV: 3.4e-03 conc: 3.6e-02
# [Epoch 73/1000] Train SV: 2.5e-02 conc: 2.3e-01 | Val SV: 3.4e-03 conc: 4.5e-02
# [Epoch 74/1000] Train SV: 2.3e-02 conc: 2.0e-01 | Val SV: 4.1e-03 conc: 3.1e-02
# [Epoch 75/1000] Train SV: 2.4e-02 conc: 2.0e-01 | Val SV: 3.6e-03 conc: 2.8e-02
# [Epoch 76/1000] Train SV: 2.4e-02 conc: 1.9e-01 | Val SV: 3.4e-03 conc: 1.9e-02
# [Epoch 77/1000] Train SV: 2.3e-02 conc: 2.1e-01 | Val SV: 3.6e-03 conc: 3.2e-02
# [Epoch 78/1000] Train SV: 2.3e-02 conc: 2.2e-01 | Val SV: 3.8e-03 conc: 5.5e-02
# [Epoch 79/1000] Train SV: 2.3e-02 conc: 1.8e-01 | Val SV: 3.7e-03 conc: 7.0e-02
# [Epoch 80/1000] Train SV: 2.2e-02 conc: 2.4e-01 | Val SV: 3.7e-03 conc: 4.0e-02
# [Epoch 81/1000] Train SV: 2.3e-02 conc: 2.1e-01 | Val SV: 3.4e-03 conc: 4.1e-02
# [Epoch 82/1000] Train SV: 2.3e-02 conc: 2.2e-01 | Val SV: 3.1e-03 conc: 2.6e-02
# [Epoch 83/1000] Train SV: 2.3e-02 conc: 1.9e-01 | Val SV: 3.1e-03 conc: 3.1e-02
# [Epoch 84/1000] Train SV: 2.2e-02 conc: 1.7e-01 | Val SV: 4.5e-03 conc: 2.8e-02
# [Epoch 85/1000] Train SV: 2.1e-02 conc: 1.9e-01 | Val SV: 3.0e-03 conc: 3.9e-02
# [Epoch 86/1000] Train SV: 2.0e-02 conc: 1.9e-01 | Val SV: 3.2e-03 conc: 5.4e-02
# [Epoch 87/1000] Train SV: 2.1e-02 conc: 1.6e-01 | Val SV: 2.7e-03 conc: 3.2e-02
# [Epoch 88/1000] Train SV: 2.0e-02 conc: 1.6e-01 | Val SV: 3.1e-03 conc: 2.6e-02
# [Epoch 89/1000] Train SV: 1.9e-02 conc: 1.5e-01 | Val SV: 2.8e-03 conc: 2.2e-02
# [Epoch 90/1000] Train SV: 2.0e-02 conc: 1.8e-01 | Val SV: 3.1e-03 conc: 4.5e-02
# [Epoch 91/1000] Train SV: 2.0e-02 conc: 1.9e-01 | Val SV: 2.9e-03 conc: 5.8e-02
# [Epoch 92/1000] Train SV: 1.9e-02 conc: 1.6e-01 | Val SV: 2.9e-03 conc: 1.6e-02
# [Epoch 93/1000] Train SV: 2.0e-02 conc: 1.6e-01 | Val SV: 3.0e-03 conc: 2.8e-02
# [Epoch 94/1000] Train SV: 1.8e-02 conc: 1.8e-01 | Val SV: 2.6e-03 conc: 3.1e-02
# [Epoch 95/1000] Train SV: 1.9e-02 conc: 1.5e-01 | Val SV: 2.8e-03 conc: 2.0e-02
# [Epoch 96/1000] Train SV: 1.8e-02 conc: 1.7e-01 | Val SV: 3.5e-03 conc: 2.1e-02
# [Epoch 97/1000] Train SV: 1.7e-02 conc: 1.5e-01 | Val SV: 2.8e-03 conc: 4.3e-02
# [Epoch 98/1000] Train SV: 1.7e-02 conc: 1.5e-01 | Val SV: 2.5e-03 conc: 2.0e-02
# [Epoch 99/1000] Train SV: 1.7e-02 conc: 1.4e-01 | Val SV: 2.6e-03 conc: 3.2e-02
# [Epoch 100/1000] Train SV: 1.8e-02 conc: 1.4e-01 | Val SV: 2.7e-03 conc: 2.6e-02
# [Epoch 101/1000] Train SV: 1.8e-02 conc: 1.5e-01 | Val SV: 3.1e-03 conc: 5.4e-02
# [Epoch 102/1000] Train SV: 1.8e-02 conc: 1.5e-01 | Val SV: 3.0e-03 conc: 2.6e-02
# [Epoch 103/1000] Train SV: 1.9e-02 conc: 1.4e-01 | Val SV: 2.7e-03 conc: 2.9e-02
# [Epoch 104/1000] Train SV: 1.7e-02 conc: 1.4e-01 | Val SV: 2.7e-03 conc: 2.0e-02
# [Epoch 105/1000] Train SV: 1.7e-02 conc: 1.4e-01 | Val SV: 3.2e-03 conc: 4.3e-02
# [Epoch 106/1000] Train SV: 1.6e-02 conc: 1.4e-01 | Val SV: 2.9e-03 conc: 6.2e-02
# [Epoch 107/1000] Train SV: 1.7e-02 conc: 1.4e-01 | Val SV: 2.6e-03 conc: 3.2e-02
# [Epoch 108/1000] Train SV: 1.7e-02 conc: 1.4e-01 | Val SV: 2.6e-03 conc: 2.9e-02
# [Epoch 109/1000] Train SV: 1.6e-02 conc: 1.3e-01 | Val SV: 2.6e-03 conc: 3.3e-02
# [Epoch 110/1000] Train SV: 1.6e-02 conc: 1.1e-01 | Val SV: 2.5e-03 conc: 2.5e-02
# [Epoch 111/1000] Train SV: 1.5e-02 conc: 1.3e-01 | Val SV: 2.3e-03 conc: 3.4e-02
# [Epoch 112/1000] Train SV: 1.4e-02 conc: 1.4e-01 | Val SV: 2.5e-03 conc: 4.2e-02
# [Epoch 113/1000] Train SV: 1.5e-02 conc: 1.3e-01 | Val SV: 2.6e-03 conc: 3.2e-02
# [Epoch 114/1000] Train SV: 1.5e-02 conc: 1.3e-01 | Val SV: 2.2e-03 conc: 3.4e-02
# [Epoch 115/1000] Train SV: 1.6e-02 conc: 1.2e-01 | Val SV: 2.2e-03 conc: 2.2e-02
# [Epoch 116/1000] Train SV: 1.4e-02 conc: 1.3e-01 | Val SV: 2.1e-03 conc: 2.0e-02
# [Epoch 117/1000] Train SV: 1.4e-02 conc: 1.1e-01 | Val SV: 2.4e-03 conc: 2.1e-02
# [Epoch 118/1000] Train SV: 1.5e-02 conc: 1.2e-01 | Val SV: 2.7e-03 conc: 2.7e-02
# [Epoch 119/1000] Train SV: 1.4e-02 conc: 1.2e-01 | Val SV: 2.1e-03 conc: 3.1e-02
# [Epoch 120/1000] Train SV: 1.4e-02 conc: 1.2e-01 | Val SV: 2.0e-03 conc: 3.5e-02
# [Epoch 121/1000] Train SV: 1.4e-02 conc: 1.3e-01 | Val SV: 2.5e-03 conc: 2.2e-02
# [Epoch 122/1000] Train SV: 1.5e-02 conc: 1.1e-01 | Val SV: 2.7e-03 conc: 2.0e-02
# [Epoch 123/1000] Train SV: 1.4e-02 conc: 1.0e-01 | Val SV: 2.6e-03 conc: 2.5e-02
# [Epoch 124/1000] Train SV: 1.5e-02 conc: 1.1e-01 | Val SV: 2.3e-03 conc: 1.9e-02
# [Epoch 125/1000] Train SV: 1.5e-02 conc: 1.1e-01 | Val SV: 2.1e-03 conc: 2.3e-02
# [Epoch 126/1000] Train SV: 1.4e-02 conc: 1.2e-01 | Val SV: 2.4e-03 conc: 1.8e-02
# [Epoch 127/1000] Train SV: 1.4e-02 conc: 1.1e-01 | Val SV: 2.1e-03 conc: 2.5e-02
# [Epoch 128/1000] Train SV: 1.4e-02 conc: 1.1e-01 | Val SV: 2.0e-03 conc: 2.8e-02
# [Epoch 129/1000] Train SV: 1.4e-02 conc: 1.1e-01 | Val SV: 2.1e-03 conc: 2.3e-02
# [Epoch 130/1000] Train SV: 1.4e-02 conc: 1.0e-01 | Val SV: 2.4e-03 conc: 2.5e-02
# [Epoch 131/1000] Train SV: 1.3e-02 conc: 1.0e-01 | Val SV: 2.2e-03 conc: 1.8e-02
# [Epoch 132/1000] Train SV: 1.3e-02 conc: 1.0e-01 | Val SV: 2.0e-03 conc: 2.0e-02
# [Epoch 133/1000] Train SV: 1.3e-02 conc: 8.3e-02 | Val SV: 2.1e-03 conc: 4.9e-02
# [Epoch 134/1000] Train SV: 1.3e-02 conc: 1.1e-01 | Val SV: 2.3e-03 conc: 2.8e-02
# [Epoch 135/1000] Train SV: 1.2e-02 conc: 1.1e-01 | Val SV: 1.9e-03 conc: 2.3e-02
# [Epoch 136/1000] Train SV: 1.3e-02 conc: 8.6e-02 | Val SV: 2.3e-03 conc: 1.6e-02
# [Epoch 137/1000] Train SV: 1.2e-02 conc: 9.0e-02 | Val SV: 2.0e-03 conc: 1.4e-02
# [Epoch 138/1000] Train SV: 1.2e-02 conc: 9.3e-02 | Val SV: 2.0e-03 conc: 1.4e-02
# [Epoch 139/1000] Train SV: 1.2e-02 conc: 8.3e-02 | Val SV: 2.0e-03 conc: 1.5e-02
# [Epoch 140/1000] Train SV: 1.2e-02 conc: 8.6e-02 | Val SV: 1.8e-03 conc: 2.2e-02
# [Epoch 141/1000] Train SV: 1.3e-02 conc: 8.3e-02 | Val SV: 1.8e-03 conc: 2.3e-02
# [Epoch 142/1000] Train SV: 1.2e-02 conc: 7.9e-02 | Val SV: 2.1e-03 conc: 2.4e-02
# [Epoch 143/1000] Train SV: 1.2e-02 conc: 9.0e-02 | Val SV: 2.1e-03 conc: 3.1e-02
# [Epoch 144/1000] Train SV: 1.2e-02 conc: 8.0e-02 | Val SV: 1.9e-03 conc: 3.5e-02
# [Epoch 145/1000] Train SV: 1.1e-02 conc: 8.5e-02 | Val SV: 1.9e-03 conc: 3.4e-02
# [Epoch 146/1000] Train SV: 1.1e-02 conc: 8.8e-02 | Val SV: 1.7e-03 conc: 2.2e-02
# [Epoch 147/1000] Train SV: 1.1e-02 conc: 8.9e-02 | Val SV: 1.7e-03 conc: 2.0e-02
# [Epoch 148/1000] Train SV: 1.2e-02 conc: 7.9e-02 | Val SV: 1.7e-03 conc: 1.8e-02
# [Epoch 149/1000] Train SV: 1.2e-02 conc: 7.4e-02 | Val SV: 2.1e-03 conc: 2.5e-02
# [Epoch 150/1000] Train SV: 1.0e-02 conc: 9.0e-02 | Val SV: 1.8e-03 conc: 2.4e-02
# [Epoch 151/1000] Train SV: 1.1e-02 conc: 7.9e-02 | Val SV: 1.7e-03 conc: 2.0e-02
# [Epoch 152/1000] Train SV: 1.1e-02 conc: 7.7e-02 | Val SV: 1.6e-03 conc: 2.6e-02
# [Epoch 153/1000] Train SV: 1.1e-02 conc: 8.1e-02 | Val SV: 1.6e-03 conc: 2.6e-02
# [Epoch 154/1000] Train SV: 1.1e-02 conc: 7.5e-02 | Val SV: 1.8e-03 conc: 2.2e-02
# [Epoch 155/1000] Train SV: 1.2e-02 conc: 8.2e-02 | Val SV: 1.8e-03 conc: 1.8e-02
# [Epoch 156/1000] Train SV: 1.0e-02 conc: 6.8e-02 | Val SV: 2.0e-03 conc: 4.0e-02
# [Epoch 157/1000] Train SV: 1.1e-02 conc: 7.3e-02 | Val SV: 1.7e-03 conc: 2.2e-02
# [Epoch 158/1000] Train SV: 1.1e-02 conc: 7.7e-02 | Val SV: 1.8e-03 conc: 2.1e-02
# [Epoch 159/1000] Train SV: 1.0e-02 conc: 6.7e-02 | Val SV: 1.9e-03 conc: 1.3e-02
# [Epoch 160/1000] Train SV: 1.1e-02 conc: 6.9e-02 | Val SV: 1.8e-03 conc: 2.1e-02
# [Epoch 161/1000] Train SV: 1.1e-02 conc: 7.2e-02 | Val SV: 2.1e-03 conc: 1.7e-02
# [Epoch 162/1000] Train SV: 1.0e-02 conc: 7.1e-02 | Val SV: 1.5e-03 conc: 1.9e-02
# [Epoch 163/1000] Train SV: 1.0e-02 conc: 7.5e-02 | Val SV: 2.0e-03 conc: 2.3e-02
# [Epoch 164/1000] Train SV: 9.4e-03 conc: 7.1e-02 | Val SV: 1.6e-03 conc: 1.2e-02
# [Epoch 165/1000] Train SV: 1.0e-02 conc: 7.2e-02 | Val SV: 1.5e-03 conc: 1.7e-02
# [Epoch 166/1000] Train SV: 1.0e-02 conc: 6.7e-02 | Val SV: 1.9e-03 conc: 1.5e-02
# [Epoch 167/1000] Train SV: 1.0e-02 conc: 6.3e-02 | Val SV: 1.6e-03 conc: 1.6e-02
# [Epoch 168/1000] Train SV: 1.0e-02 conc: 6.7e-02 | Val SV: 2.0e-03 conc: 2.0e-02
# [Epoch 169/1000] Train SV: 1.1e-02 conc: 6.3e-02 | Val SV: 1.4e-03 conc: 2.4e-02
# [Epoch 170/1000] Train SV: 9.3e-03 conc: 6.0e-02 | Val SV: 1.6e-03 conc: 2.2e-02
# [Epoch 171/1000] Train SV: 1.0e-02 conc: 7.6e-02 | Val SV: 1.7e-03 conc: 1.6e-02
# [Epoch 172/1000] Train SV: 9.4e-03 conc: 6.6e-02 | Val SV: 1.7e-03 conc: 1.3e-02
# [Epoch 173/1000] Train SV: 9.1e-03 conc: 5.5e-02 | Val SV: 1.5e-03 conc: 1.7e-02
# [Epoch 174/1000] Train SV: 1.0e-02 conc: 6.0e-02 | Val SV: 1.4e-03 conc: 1.6e-02
# [Epoch 175/1000] Train SV: 1.1e-02 conc: 5.4e-02 | Val SV: 1.6e-03 conc: 1.4e-02
# [Epoch 176/1000] Train SV: 1.0e-02 conc: 4.7e-02 | Val SV: 1.7e-03 conc: 1.2e-02
# [Epoch 177/1000] Train SV: 9.2e-03 conc: 6.0e-02 | Val SV: 1.5e-03 conc: 2.2e-02
# [Epoch 178/1000] Train SV: 9.0e-03 conc: 6.0e-02 | Val SV: 1.4e-03 conc: 1.7e-02
# [Epoch 179/1000] Train SV: 9.8e-03 conc: 5.7e-02 | Val SV: 1.5e-03 conc: 1.3e-02
# [Epoch 180/1000] Train SV: 8.2e-03 conc: 5.5e-02 | Val SV: 1.5e-03 conc: 1.4e-02
# [Epoch 181/1000] Train SV: 1.0e-02 conc: 4.7e-02 | Val SV: 1.4e-03 conc: 1.1e-02
# [Epoch 182/1000] Train SV: 9.0e-03 conc: 5.0e-02 | Val SV: 1.6e-03 conc: 2.6e-02
# [Epoch 183/1000] Train SV: 9.9e-03 conc: 5.6e-02 | Val SV: 2.2e-03 conc: 1.5e-02
# [Epoch 184/1000] Train SV: 8.9e-03 conc: 5.4e-02 | Val SV: 1.4e-03 conc: 9.0e-03
# [Epoch 185/1000] Train SV: 9.9e-03 conc: 5.6e-02 | Val SV: 1.8e-03 conc: 2.1e-02
# [Epoch 186/1000] Train SV: 9.0e-03 conc: 5.3e-02 | Val SV: 1.3e-03 conc: 1.6e-02
# [Epoch 187/1000] Train SV: 8.4e-03 conc: 5.1e-02 | Val SV: 1.4e-03 conc: 1.5e-02
# [Epoch 188/1000] Train SV: 8.8e-03 conc: 5.2e-02 | Val SV: 1.3e-03 conc: 1.6e-02
# [Epoch 189/1000] Train SV: 8.4e-03 conc: 5.8e-02 | Val SV: 1.6e-03 conc: 1.5e-02
# [Epoch 190/1000] Train SV: 8.8e-03 conc: 5.5e-02 | Val SV: 1.4e-03 conc: 2.3e-02
# [Epoch 191/1000] Train SV: 8.0e-03 conc: 4.5e-02 | Val SV: 1.3e-03 conc: 1.3e-02
# [Epoch 192/1000] Train SV: 9.2e-03 conc: 5.1e-02 | Val SV: 1.4e-03 conc: 1.3e-02
# [Epoch 193/1000] Train SV: 8.4e-03 conc: 5.5e-02 | Val SV: 1.3e-03 conc: 1.4e-02
# [Epoch 194/1000] Train SV: 8.3e-03 conc: 4.6e-02 | Val SV: 1.7e-03 conc: 9.9e-03
# [Epoch 195/1000] Train SV: 8.2e-03 conc: 4.4e-02 | Val SV: 1.4e-03 conc: 1.9e-02
# [Epoch 196/1000] Train SV: 8.7e-03 conc: 5.9e-02 | Val SV: 1.5e-03 conc: 2.6e-02
# [Epoch 197/1000] Train SV: 7.9e-03 conc: 4.4e-02 | Val SV: 1.6e-03 conc: 1.3e-02
# [Epoch 198/1000] Train SV: 8.5e-03 conc: 4.9e-02 | Val SV: 1.4e-03 conc: 1.8e-02
# [Epoch 199/1000] Train SV: 8.2e-03 conc: 4.4e-02 | Val SV: 1.3e-03 conc: 1.8e-02
# [Epoch 200/1000] Train SV: 8.2e-03 conc: 4.9e-02 | Val SV: 1.6e-03 conc: 1.3e-02
# [Epoch 201/1000] Train SV: 8.0e-03 conc: 4.4e-02 | Val SV: 1.3e-03 conc: 1.9e-02
# [Epoch 202/1000] Train SV: 7.8e-03 conc: 4.2e-02 | Val SV: 1.5e-03 conc: 1.3e-02
# [Epoch 203/1000] Train SV: 7.6e-03 conc: 4.0e-02 | Val SV: 1.2e-03 conc: 2.4e-02
# [Epoch 204/1000] Train SV: 8.0e-03 conc: 4.4e-02 | Val SV: 1.4e-03 conc: 1.4e-02
# [Epoch 205/1000] Train SV: 8.1e-03 conc: 4.7e-02 | Val SV: 1.3e-03 conc: 2.8e-02
# [Epoch 206/1000] Train SV: 7.6e-03 conc: 4.6e-02 | Val SV: 1.2e-03 conc: 2.3e-02
# [Epoch 207/1000] Train SV: 7.6e-03 conc: 4.5e-02 | Val SV: 1.1e-03 conc: 1.8e-02
# [Epoch 208/1000] Train SV: 7.3e-03 conc: 4.2e-02 | Val SV: 1.3e-03 conc: 1.5e-02
# [Epoch 209/1000] Train SV: 7.2e-03 conc: 4.2e-02 | Val SV: 1.1e-03 conc: 1.4e-02
# [Epoch 210/1000] Train SV: 8.0e-03 conc: 4.2e-02 | Val SV: 1.3e-03 conc: 1.3e-02
# [Epoch 211/1000] Train SV: 7.5e-03 conc: 4.0e-02 | Val SV: 1.2e-03 conc: 1.5e-02
# [Epoch 212/1000] Train SV: 7.3e-03 conc: 4.2e-02 | Val SV: 1.2e-03 conc: 1.4e-02
# [Epoch 213/1000] Train SV: 7.4e-03 conc: 4.4e-02 | Val SV: 1.1e-03 conc: 1.8e-02
# [Epoch 214/1000] Train SV: 8.3e-03 conc: 4.4e-02 | Val SV: 1.2e-03 conc: 2.3e-02
# [Epoch 215/1000] Train SV: 7.1e-03 conc: 4.7e-02 | Val SV: 1.1e-03 conc: 1.8e-02
# [Epoch 216/1000] Train SV: 7.3e-03 conc: 3.9e-02 | Val SV: 1.3e-03 conc: 1.3e-02
# [Epoch 217/1000] Train SV: 7.3e-03 conc: 4.5e-02 | Val SV: 1.1e-03 conc: 1.1e-02
# [Epoch 218/1000] Train SV: 7.1e-03 conc: 4.3e-02 | Val SV: 1.1e-03 conc: 1.2e-02
# [Epoch 219/1000] Train SV: 7.1e-03 conc: 3.7e-02 | Val SV: 1.3e-03 conc: 1.3e-02
# [Epoch 220/1000] Train SV: 7.5e-03 conc: 3.6e-02 | Val SV: 1.1e-03 conc: 8.8e-03
# [Epoch 221/1000] Train SV: 7.1e-03 conc: 4.1e-02 | Val SV: 1.2e-03 conc: 1.0e-02
# [Epoch 222/1000] Train SV: 7.1e-03 conc: 3.8e-02 | Val SV: 1.3e-03 conc: 2.1e-02
# [Epoch 223/1000] Train SV: 6.8e-03 conc: 3.9e-02 | Val SV: 1.2e-03 conc: 1.4e-02
# [Epoch 224/1000] Train SV: 7.7e-03 conc: 3.4e-02 | Val SV: 1.1e-03 conc: 1.5e-02
# [Epoch 225/1000] Train SV: 6.8e-03 conc: 3.3e-02 | Val SV: 1.1e-03 conc: 9.4e-03
# [Epoch 226/1000] Train SV: 7.1e-03 conc: 3.9e-02 | Val SV: 1.0e-03 conc: 1.2e-02
# [Epoch 227/1000] Train SV: 7.1e-03 conc: 3.4e-02 | Val SV: 1.1e-03 conc: 8.1e-03
# [Epoch 228/1000] Train SV: 6.8e-03 conc: 3.8e-02 | Val SV: 1.0e-03 conc: 1.8e-02
# [Epoch 229/1000] Train SV: 6.9e-03 conc: 3.8e-02 | Val SV: 1.1e-03 conc: 1.9e-02
# [Epoch 230/1000] Train SV: 7.4e-03 conc: 4.3e-02 | Val SV: 1.1e-03 conc: 2.3e-02
# [Epoch 231/1000] Train SV: 7.1e-03 conc: 3.5e-02 | Val SV: 1.1e-03 conc: 8.9e-03
# [Epoch 232/1000] Train SV: 6.5e-03 conc: 3.6e-02 | Val SV: 1.2e-03 conc: 2.1e-02
# [Epoch 233/1000] Train SV: 7.2e-03 conc: 3.2e-02 | Val SV: 1.1e-03 conc: 1.2e-02
# [Epoch 234/1000] Train SV: 6.3e-03 conc: 3.2e-02 | Val SV: 9.6e-04 conc: 1.4e-02
# [Epoch 235/1000] Train SV: 6.6e-03 conc: 3.4e-02 | Val SV: 1.1e-03 conc: 8.3e-03
# [Epoch 236/1000] Train SV: 7.0e-03 conc: 3.1e-02 | Val SV: 1.0e-03 conc: 1.2e-02
# [Epoch 237/1000] Train SV: 6.2e-03 conc: 3.2e-02 | Val SV: 1.0e-03 conc: 1.4e-02
# [Epoch 238/1000] Train SV: 6.5e-03 conc: 2.8e-02 | Val SV: 1.1e-03 conc: 8.6e-03
# [Epoch 239/1000] Train SV: 7.3e-03 conc: 2.7e-02 | Val SV: 1.0e-03 conc: 9.2e-03
# [Epoch 240/1000] Train SV: 5.8e-03 conc: 3.0e-02 | Val SV: 1.1e-03 conc: 1.4e-02
# [Epoch 241/1000] Train SV: 6.2e-03 conc: 3.3e-02 | Val SV: 9.9e-04 conc: 1.2e-02
# [Epoch 242/1000] Train SV: 6.2e-03 conc: 3.4e-02 | Val SV: 1.1e-03 conc: 1.3e-02
# [Epoch 243/1000] Train SV: 6.0e-03 conc: 3.2e-02 | Val SV: 1.1e-03 conc: 1.2e-02
# [Epoch 244/1000] Train SV: 5.9e-03 conc: 3.4e-02 | Val SV: 9.6e-04 conc: 9.0e-03
# [Epoch 245/1000] Train SV: 6.5e-03 conc: 3.0e-02 | Val SV: 9.8e-04 conc: 8.7e-03
# [Epoch 246/1000] Train SV: 6.4e-03 conc: 2.8e-02 | Val SV: 1.0e-03 conc: 7.4e-03
# [Epoch 247/1000] Train SV: 6.1e-03 conc: 2.9e-02 | Val SV: 1.0e-03 conc: 1.2e-02
# [Epoch 248/1000] Train SV: 6.3e-03 conc: 2.8e-02 | Val SV: 1.1e-03 conc: 9.0e-03
# [Epoch 249/1000] Train SV: 6.0e-03 conc: 2.9e-02 | Val SV: 9.6e-04 conc: 1.1e-02
# [Epoch 250/1000] Train SV: 6.3e-03 conc: 3.1e-02 | Val SV: 1.2e-03 conc: 8.1e-03
# [Epoch 251/1000] Train SV: 6.2e-03 conc: 3.3e-02 | Val SV: 9.9e-04 conc: 1.1e-02
# [Epoch 252/1000] Train SV: 6.6e-03 conc: 2.8e-02 | Val SV: 1.1e-03 conc: 9.7e-03
# [Epoch 253/1000] Train SV: 5.8e-03 conc: 2.7e-02 | Val SV: 9.6e-04 conc: 1.2e-02
# [Epoch 254/1000] Train SV: 6.4e-03 conc: 3.0e-02 | Val SV: 1.0e-03 conc: 1.1e-02
# [Epoch 255/1000] Train SV: 6.0e-03 conc: 2.8e-02 | Val SV: 9.2e-04 conc: 1.1e-02
# [Epoch 256/1000] Train SV: 5.7e-03 conc: 3.1e-02 | Val SV: 1.2e-03 conc: 9.0e-03
# [Epoch 257/1000] Train SV: 5.2e-03 conc: 2.8e-02 | Val SV: 8.5e-04 conc: 1.2e-02
# [Epoch 258/1000] Train SV: 5.8e-03 conc: 2.6e-02 | Val SV: 9.6e-04 conc: 8.9e-03
# [Epoch 259/1000] Train SV: 5.7e-03 conc: 2.9e-02 | Val SV: 8.7e-04 conc: 9.5e-03
# [Epoch 260/1000] Train SV: 6.0e-03 conc: 2.5e-02 | Val SV: 1.3e-03 conc: 9.9e-03
# [Epoch 261/1000] Train SV: 5.9e-03 conc: 2.4e-02 | Val SV: 9.4e-04 conc: 1.1e-02
# [Epoch 262/1000] Train SV: 5.6e-03 conc: 2.9e-02 | Val SV: 9.5e-04 conc: 1.3e-02
# [Epoch 263/1000] Train SV: 5.1e-03 conc: 2.5e-02 | Val SV: 9.6e-04 conc: 7.9e-03
# [Epoch 264/1000] Train SV: 5.8e-03 conc: 2.5e-02 | Val SV: 9.2e-04 conc: 1.1e-02
# [Epoch 265/1000] Train SV: 5.2e-03 conc: 2.4e-02 | Val SV: 9.0e-04 conc: 8.4e-03
# [Epoch 266/1000] Train SV: 5.7e-03 conc: 2.2e-02 | Val SV: 8.7e-04 conc: 1.0e-02
# [Epoch 267/1000] Train SV: 5.4e-03 conc: 2.2e-02 | Val SV: 1.0e-03 conc: 8.7e-03
# [Epoch 268/1000] Train SV: 5.5e-03 conc: 2.2e-02 | Val SV: 1.0e-03 conc: 1.3e-02
# [Epoch 269/1000] Train SV: 5.4e-03 conc: 2.5e-02 | Val SV: 8.7e-04 conc: 1.3e-02
# [Epoch 270/1000] Train SV: 5.4e-03 conc: 2.7e-02 | Val SV: 9.9e-04 conc: 1.3e-02
# [Epoch 271/1000] Train SV: 6.2e-03 conc: 2.7e-02 | Val SV: 1.1e-03 conc: 8.6e-03
# [Epoch 272/1000] Train SV: 6.0e-03 conc: 2.7e-02 | Val SV: 8.3e-04 conc: 1.1e-02
# [Epoch 273/1000] Train SV: 5.7e-03 conc: 2.3e-02 | Val SV: 8.2e-04 conc: 1.2e-02
# [Epoch 274/1000] Train SV: 5.2e-03 conc: 2.1e-02 | Val SV: 9.1e-04 conc: 9.4e-03
# [Epoch 275/1000] Train SV: 5.6e-03 conc: 2.9e-02 | Val SV: 9.1e-04 conc: 1.2e-02
# [Epoch 276/1000] Train SV: 5.6e-03 conc: 2.2e-02 | Val SV: 8.9e-04 conc: 8.8e-03
# [Epoch 277/1000] Train SV: 5.5e-03 conc: 2.2e-02 | Val SV: 1.0e-03 conc: 7.6e-03
# [Epoch 278/1000] Train SV: 4.9e-03 conc: 2.5e-02 | Val SV: 1.1e-03 conc: 9.5e-03
# [Epoch 279/1000] Train SV: 5.8e-03 conc: 2.5e-02 | Val SV: 9.8e-04 conc: 1.3e-02
# [Epoch 280/1000] Train SV: 5.2e-03 conc: 2.2e-02 | Val SV: 8.7e-04 conc: 8.4e-03
# [Epoch 281/1000] Train SV: 5.4e-03 conc: 2.2e-02 | Val SV: 8.6e-04 conc: 7.0e-03
# [Epoch 282/1000] Train SV: 5.1e-03 conc: 2.3e-02 | Val SV: 8.0e-04 conc: 8.0e-03
# [Epoch 283/1000] Train SV: 4.7e-03 conc: 2.1e-02 | Val SV: 1.1e-03 conc: 8.2e-03
# [Epoch 284/1000] Train SV: 4.8e-03 conc: 2.3e-02 | Val SV: 8.1e-04 conc: 1.5e-02
# [Epoch 285/1000] Train SV: 4.8e-03 conc: 2.2e-02 | Val SV: 8.5e-04 conc: 8.5e-03
# [Epoch 286/1000] Train SV: 5.3e-03 conc: 2.4e-02 | Val SV: 8.6e-04 conc: 8.4e-03
# [Epoch 287/1000] Train SV: 5.3e-03 conc: 2.0e-02 | Val SV: 7.9e-04 conc: 8.4e-03
# [Epoch 288/1000] Train SV: 5.1e-03 conc: 2.0e-02 | Val SV: 8.1e-04 conc: 1.1e-02
# [Epoch 289/1000] Train SV: 5.6e-03 conc: 2.0e-02 | Val SV: 7.4e-04 conc: 1.0e-02
# [Epoch 290/1000] Train SV: 5.1e-03 conc: 2.0e-02 | Val SV: 7.7e-04 conc: 7.8e-03
# [Epoch 291/1000] Train SV: 4.8e-03 conc: 2.0e-02 | Val SV: 8.3e-04 conc: 8.0e-03
# [Epoch 292/1000] Train SV: 4.8e-03 conc: 2.0e-02 | Val SV: 8.2e-04 conc: 6.9e-03
# [Epoch 293/1000] Train SV: 4.8e-03 conc: 2.2e-02 | Val SV: 8.2e-04 conc: 1.4e-02
# [Epoch 294/1000] Train SV: 4.7e-03 conc: 2.1e-02 | Val SV: 7.8e-04 conc: 8.6e-03
# [Epoch 295/1000] Train SV: 5.1e-03 conc: 1.9e-02 | Val SV: 8.0e-04 conc: 8.6e-03
# [Epoch 296/1000] Train SV: 4.8e-03 conc: 2.1e-02 | Val SV: 9.0e-04 conc: 6.6e-03
# [Epoch 297/1000] Train SV: 4.6e-03 conc: 1.9e-02 | Val SV: 7.2e-04 conc: 1.0e-02
# [Epoch 298/1000] Train SV: 4.6e-03 conc: 2.0e-02 | Val SV: 7.4e-04 conc: 8.1e-03
# [Epoch 299/1000] Train SV: 4.5e-03 conc: 2.0e-02 | Val SV: 8.4e-04 conc: 1.4e-02
# [Epoch 300/1000] Train SV: 5.0e-03 conc: 1.9e-02 | Val SV: 8.2e-04 conc: 1.0e-02
# [Epoch 301/1000] Train SV: 4.9e-03 conc: 1.8e-02 | Val SV: 9.5e-04 conc: 1.1e-02
# [Epoch 302/1000] Train SV: 4.4e-03 conc: 1.9e-02 | Val SV: 7.8e-04 conc: 9.5e-03
# [Epoch 303/1000] Train SV: 4.7e-03 conc: 2.0e-02 | Val SV: 9.0e-04 conc: 8.0e-03
# [Epoch 304/1000] Train SV: 4.8e-03 conc: 1.9e-02 | Val SV: 7.9e-04 conc: 1.3e-02
# [Epoch 305/1000] Train SV: 4.8e-03 conc: 2.3e-02 | Val SV: 7.7e-04 conc: 8.4e-03
# [Epoch 306/1000] Train SV: 5.0e-03 conc: 2.1e-02 | Val SV: 8.6e-04 conc: 9.6e-03
# [Epoch 307/1000] Train SV: 4.4e-03 conc: 1.9e-02 | Val SV: 7.4e-04 conc: 9.8e-03
# [Epoch 308/1000] Train SV: 4.1e-03 conc: 1.8e-02 | Val SV: 7.2e-04 conc: 7.6e-03
# [Epoch 309/1000] Train SV: 4.5e-03 conc: 1.7e-02 | Val SV: 6.9e-04 conc: 1.1e-02
# [Epoch 310/1000] Train SV: 4.3e-03 conc: 1.9e-02 | Val SV: 7.7e-04 conc: 9.6e-03
# [Epoch 311/1000] Train SV: 4.6e-03 conc: 1.7e-02 | Val SV: 7.7e-04 conc: 9.1e-03
# [Epoch 312/1000] Train SV: 4.5e-03 conc: 1.6e-02 | Val SV: 7.9e-04 conc: 7.1e-03
# [Epoch 313/1000] Train SV: 4.4e-03 conc: 1.8e-02 | Val SV: 9.4e-04 conc: 7.4e-03
# [Epoch 314/1000] Train SV: 4.7e-03 conc: 1.7e-02 | Val SV: 7.9e-04 conc: 8.0e-03
# [Epoch 315/1000] Train SV: 4.4e-03 conc: 1.7e-02 | Val SV: 7.3e-04 conc: 1.0e-02
# [Epoch 316/1000] Train SV: 4.3e-03 conc: 1.8e-02 | Val SV: 7.0e-04 conc: 9.0e-03
# [Epoch 317/1000] Train SV: 4.7e-03 conc: 1.6e-02 | Val SV: 7.1e-04 conc: 6.5e-03
# [Epoch 318/1000] Train SV: 4.1e-03 conc: 1.8e-02 | Val SV: 7.2e-04 conc: 7.9e-03
# [Epoch 319/1000] Train SV: 4.8e-03 conc: 1.7e-02 | Val SV: 7.8e-04 conc: 6.7e-03
# [Epoch 320/1000] Train SV: 4.4e-03 conc: 1.7e-02 | Val SV: 7.6e-04 conc: 9.6e-03
# [Epoch 321/1000] Train SV: 4.6e-03 conc: 1.6e-02 | Val SV: 7.2e-04 conc: 9.0e-03
# [Epoch 322/1000] Train SV: 4.5e-03 conc: 1.7e-02 | Val SV: 7.7e-04 conc: 6.1e-03
# [Epoch 323/1000] Train SV: 4.2e-03 conc: 1.6e-02 | Val SV: 7.6e-04 conc: 8.6e-03
# [Epoch 324/1000] Train SV: 4.3e-03 conc: 1.7e-02 | Val SV: 7.0e-04 conc: 7.4e-03
# [Epoch 325/1000] Train SV: 4.9e-03 conc: 1.6e-02 | Val SV: 7.8e-04 conc: 7.8e-03
# [Epoch 326/1000] Train SV: 4.2e-03 conc: 1.5e-02 | Val SV: 7.4e-04 conc: 7.4e-03
# [Epoch 327/1000] Train SV: 4.3e-03 conc: 1.8e-02 | Val SV: 7.0e-04 conc: 9.7e-03
# [Epoch 328/1000] Train SV: 4.2e-03 conc: 1.5e-02 | Val SV: 7.7e-04 conc: 6.5e-03
# [Epoch 329/1000] Train SV: 4.2e-03 conc: 1.5e-02 | Val SV: 7.0e-04 conc: 6.6e-03
# [Epoch 330/1000] Train SV: 4.5e-03 conc: 1.4e-02 | Val SV: 6.5e-04 conc: 6.8e-03
# [Epoch 331/1000] Train SV: 4.3e-03 conc: 1.5e-02 | Val SV: 7.0e-04 conc: 7.0e-03
# [Epoch 332/1000] Train SV: 4.3e-03 conc: 1.4e-02 | Val SV: 6.6e-04 conc: 1.2e-02
# [Epoch 333/1000] Train SV: 4.2e-03 conc: 1.6e-02 | Val SV: 8.1e-04 conc: 7.1e-03
# [Epoch 334/1000] Train SV: 4.3e-03 conc: 1.8e-02 | Val SV: 6.8e-04 conc: 9.5e-03
# [Epoch 335/1000] Train SV: 4.4e-03 conc: 1.8e-02 | Val SV: 6.8e-04 conc: 8.9e-03
# [Epoch 336/1000] Train SV: 4.1e-03 conc: 1.6e-02 | Val SV: 8.3e-04 conc: 8.7e-03
# [Epoch 337/1000] Train SV: 4.1e-03 conc: 1.5e-02 | Val SV: 6.9e-04 conc: 8.6e-03
# [Epoch 338/1000] Train SV: 3.8e-03 conc: 1.5e-02 | Val SV: 7.9e-04 conc: 7.4e-03
# [Epoch 339/1000] Train SV: 4.2e-03 conc: 1.4e-02 | Val SV: 7.4e-04 conc: 7.6e-03
# [Epoch 340/1000] Train SV: 3.8e-03 conc: 1.6e-02 | Val SV: 6.5e-04 conc: 7.0e-03
# [Epoch 341/1000] Train SV: 3.7e-03 conc: 1.3e-02 | Val SV: 6.5e-04 conc: 6.5e-03
# [Epoch 342/1000] Train SV: 4.1e-03 conc: 1.5e-02 | Val SV: 7.4e-04 conc: 6.6e-03
# [Epoch 343/1000] Train SV: 3.8e-03 conc: 1.3e-02 | Val SV: 6.8e-04 conc: 5.8e-03
# [Epoch 344/1000] Train SV: 4.0e-03 conc: 1.5e-02 | Val SV: 6.9e-04 conc: 7.6e-03
# [Epoch 345/1000] Train SV: 4.0e-03 conc: 1.5e-02 | Val SV: 6.5e-04 conc: 1.1e-02
# [Epoch 346/1000] Train SV: 4.0e-03 conc: 1.4e-02 | Val SV: 6.5e-04 conc: 7.9e-03
# [Epoch 347/1000] Train SV: 3.8e-03 conc: 1.4e-02 | Val SV: 7.2e-04 conc: 1.2e-02
# [Epoch 348/1000] Train SV: 3.9e-03 conc: 1.6e-02 | Val SV: 8.3e-04 conc: 7.1e-03
# [Epoch 349/1000] Train SV: 3.9e-03 conc: 1.5e-02 | Val SV: 7.0e-04 conc: 6.7e-03
# [Epoch 350/1000] Train SV: 3.9e-03 conc: 1.3e-02 | Val SV: 7.2e-04 conc: 8.1e-03
# [Epoch 351/1000] Train SV: 3.9e-03 conc: 1.4e-02 | Val SV: 6.2e-04 conc: 6.3e-03
# [Epoch 352/1000] Train SV: 3.7e-03 conc: 1.3e-02 | Val SV: 6.4e-04 conc: 6.3e-03
# [Epoch 353/1000] Train SV: 3.7e-03 conc: 1.2e-02 | Val SV: 6.5e-04 conc: 8.5e-03
# [Epoch 354/1000] Train SV: 4.0e-03 conc: 1.3e-02 | Val SV: 6.4e-04 conc: 6.7e-03
# [Epoch 355/1000] Train SV: 3.9e-03 conc: 1.4e-02 | Val SV: 6.0e-04 conc: 8.6e-03
# [Epoch 356/1000] Train SV: 3.8e-03 conc: 1.3e-02 | Val SV: 6.5e-04 conc: 8.5e-03
# [Epoch 357/1000] Train SV: 3.9e-03 conc: 1.3e-02 | Val SV: 6.3e-04 conc: 5.4e-03
# [Epoch 358/1000] Train SV: 3.8e-03 conc: 1.3e-02 | Val SV: 6.0e-04 conc: 6.4e-03
# [Epoch 359/1000] Train SV: 3.7e-03 conc: 1.2e-02 | Val SV: 6.1e-04 conc: 8.3e-03
# [Epoch 360/1000] Train SV: 3.6e-03 conc: 1.4e-02 | Val SV: 6.5e-04 conc: 9.8e-03
# [Epoch 361/1000] Train SV: 3.5e-03 conc: 1.4e-02 | Val SV: 6.8e-04 conc: 6.7e-03
# [Epoch 362/1000] Train SV: 3.9e-03 conc: 1.2e-02 | Val SV: 6.6e-04 conc: 6.5e-03
# [Epoch 363/1000] Train SV: 3.8e-03 conc: 1.2e-02 | Val SV: 8.3e-04 conc: 7.7e-03
# [Epoch 364/1000] Train SV: 3.8e-03 conc: 1.4e-02 | Val SV: 6.5e-04 conc: 6.6e-03
# [Epoch 365/1000] Train SV: 3.5e-03 conc: 1.3e-02 | Val SV: 6.6e-04 conc: 8.2e-03
# [Epoch 366/1000] Train SV: 3.5e-03 conc: 1.4e-02 | Val SV: 6.8e-04 conc: 7.6e-03
# [Epoch 367/1000] Train SV: 3.7e-03 conc: 1.2e-02 | Val SV: 6.3e-04 conc: 8.5e-03
# [Epoch 368/1000] Train SV: 3.3e-03 conc: 1.3e-02 | Val SV: 6.5e-04 conc: 6.4e-03
# [Epoch 369/1000] Train SV: 3.6e-03 conc: 1.2e-02 | Val SV: 6.0e-04 conc: 6.7e-03
# [Epoch 370/1000] Train SV: 3.7e-03 conc: 1.1e-02 | Val SV: 6.4e-04 conc: 5.8e-03
# [Epoch 371/1000] Train SV: 3.7e-03 conc: 1.2e-02 | Val SV: 6.3e-04 conc: 9.0e-03
# [Epoch 372/1000] Train SV: 3.3e-03 conc: 1.4e-02 | Val SV: 5.8e-04 conc: 6.2e-03
# [Epoch 373/1000] Train SV: 3.5e-03 conc: 1.3e-02 | Val SV: 6.6e-04 conc: 9.9e-03
# [Epoch 374/1000] Train SV: 3.9e-03 conc: 1.4e-02 | Val SV: 6.8e-04 conc: 1.1e-02
# [Epoch 375/1000] Train SV: 3.8e-03 conc: 1.4e-02 | Val SV: 6.5e-04 conc: 6.2e-03
# [Epoch 376/1000] Train SV: 3.5e-03 conc: 1.2e-02 | Val SV: 6.9e-04 conc: 7.1e-03
# [Epoch 377/1000] Train SV: 3.6e-03 conc: 1.2e-02 | Val SV: 6.0e-04 conc: 5.9e-03
# [Epoch 378/1000] Train SV: 3.4e-03 conc: 1.1e-02 | Val SV: 5.7e-04 conc: 4.9e-03
# [Epoch 379/1000] Train SV: 3.6e-03 conc: 1.2e-02 | Val SV: 6.2e-04 conc: 5.6e-03
# [Epoch 380/1000] Train SV: 3.7e-03 conc: 1.2e-02 | Val SV: 6.2e-04 conc: 7.7e-03
# [Epoch 381/1000] Train SV: 3.7e-03 conc: 1.1e-02 | Val SV: 5.8e-04 conc: 6.0e-03
# [Epoch 382/1000] Train SV: 3.5e-03 conc: 1.2e-02 | Val SV: 5.9e-04 conc: 6.9e-03
# [Epoch 383/1000] Train SV: 3.7e-03 conc: 1.2e-02 | Val SV: 6.8e-04 conc: 6.6e-03
# [Epoch 384/1000] Train SV: 3.2e-03 conc: 1.3e-02 | Val SV: 6.7e-04 conc: 5.9e-03
# [Epoch 385/1000] Train SV: 3.4e-03 conc: 1.3e-02 | Val SV: 6.5e-04 conc: 8.6e-03
# [Epoch 386/1000] Train SV: 3.5e-03 conc: 1.2e-02 | Val SV: 5.8e-04 conc: 7.1e-03
# [Epoch 387/1000] Train SV: 3.3e-03 conc: 1.1e-02 | Val SV: 5.8e-04 conc: 7.9e-03
# [Epoch 388/1000] Train SV: 3.1e-03 conc: 1.0e-02 | Val SV: 6.1e-04 conc: 5.9e-03
# [Epoch 389/1000] Train SV: 3.3e-03 conc: 1.0e-02 | Val SV: 5.8e-04 conc: 5.3e-03
# [Epoch 390/1000] Train SV: 3.2e-03 conc: 1.2e-02 | Val SV: 5.8e-04 conc: 6.2e-03
# [Epoch 391/1000] Train SV: 3.3e-03 conc: 1.2e-02 | Val SV: 5.7e-04 conc: 6.5e-03
# [Epoch 392/1000] Train SV: 3.1e-03 conc: 1.1e-02 | Val SV: 5.6e-04 conc: 6.3e-03
# [Epoch 393/1000] Train SV: 3.3e-03 conc: 1.1e-02 | Val SV: 5.7e-04 conc: 6.4e-03
# [Epoch 394/1000] Train SV: 3.4e-03 conc: 1.1e-02 | Val SV: 5.4e-04 conc: 6.6e-03
# [Epoch 395/1000] Train SV: 3.4e-03 conc: 1.0e-02 | Val SV: 5.4e-04 conc: 5.8e-03
# [Epoch 396/1000] Train SV: 3.3e-03 conc: 1.1e-02 | Val SV: 6.1e-04 conc: 5.5e-03
# [Epoch 397/1000] Train SV: 3.4e-03 conc: 9.8e-03 | Val SV: 5.5e-04 conc: 6.0e-03
# [Epoch 398/1000] Train SV: 3.2e-03 conc: 1.0e-02 | Val SV: 5.9e-04 conc: 5.5e-03
# [Epoch 399/1000] Train SV: 3.4e-03 conc: 1.0e-02 | Val SV: 5.6e-04 conc: 5.6e-03
# [Epoch 400/1000] Train SV: 3.3e-03 conc: 1.1e-02 | Val SV: 5.8e-04 conc: 6.9e-03
# [Epoch 401/1000] Train SV: 3.1e-03 conc: 1.2e-02 | Val SV: 6.1e-04 conc: 7.2e-03
# [Epoch 402/1000] Train SV: 3.1e-03 conc: 1.0e-02 | Val SV: 7.0e-04 conc: 6.0e-03
# [Epoch 403/1000] Train SV: 3.0e-03 conc: 9.6e-03 | Val SV: 5.5e-04 conc: 7.0e-03
# [Epoch 404/1000] Train SV: 3.1e-03 conc: 1.2e-02 | Val SV: 5.3e-04 conc: 5.6e-03
# [Epoch 405/1000] Train SV: 3.3e-03 conc: 1.0e-02 | Val SV: 5.3e-04 conc: 5.9e-03
# [Epoch 406/1000] Train SV: 3.0e-03 conc: 9.5e-03 | Val SV: 5.6e-04 conc: 5.6e-03
# [Epoch 407/1000] Train SV: 3.4e-03 conc: 1.1e-02 | Val SV: 5.3e-04 conc: 5.4e-03
# [Epoch 408/1000] Train SV: 3.1e-03 conc: 1.0e-02 | Val SV: 5.4e-04 conc: 6.0e-03
# [Epoch 409/1000] Train SV: 3.1e-03 conc: 9.0e-03 | Val SV: 6.1e-04 conc: 8.6e-03
# [Epoch 410/1000] Train SV: 3.3e-03 conc: 1.2e-02 | Val SV: 6.3e-04 conc: 6.8e-03
# [Epoch 411/1000] Train SV: 3.1e-03 conc: 9.5e-03 | Val SV: 6.0e-04 conc: 6.2e-03
# [Epoch 412/1000] Train SV: 3.1e-03 conc: 1.0e-02 | Val SV: 5.3e-04 conc: 7.1e-03
# [Epoch 413/1000] Train SV: 3.4e-03 conc: 9.6e-03 | Val SV: 5.8e-04 conc: 5.7e-03
# [Epoch 414/1000] Train SV: 2.9e-03 conc: 1.0e-02 | Val SV: 5.5e-04 conc: 5.5e-03
# [Epoch 415/1000] Train SV: 3.0e-03 conc: 9.3e-03 | Val SV: 5.5e-04 conc: 6.0e-03
# [Epoch 416/1000] Train SV: 3.4e-03 conc: 1.1e-02 | Val SV: 5.0e-04 conc: 5.4e-03
# [Epoch 417/1000] Train SV: 3.0e-03 conc: 9.4e-03 | Val SV: 5.2e-04 conc: 5.4e-03
# [Epoch 418/1000] Train SV: 3.2e-03 conc: 1.0e-02 | Val SV: 5.2e-04 conc: 5.6e-03
# [Epoch 419/1000] Train SV: 2.8e-03 conc: 1.1e-02 | Val SV: 5.1e-04 conc: 6.0e-03
# [Epoch 420/1000] Train SV: 3.1e-03 conc: 1.0e-02 | Val SV: 5.3e-04 conc: 5.7e-03
# [Epoch 421/1000] Train SV: 3.0e-03 conc: 9.3e-03 | Val SV: 5.1e-04 conc: 5.9e-03
# [Epoch 422/1000] Train SV: 3.1e-03 conc: 9.4e-03 | Val SV: 5.9e-04 conc: 6.8e-03
# [Epoch 423/1000] Train SV: 3.0e-03 conc: 9.6e-03 | Val SV: 5.4e-04 conc: 6.0e-03
# [Epoch 424/1000] Train SV: 2.8e-03 conc: 9.8e-03 | Val SV: 5.2e-04 conc: 7.1e-03
# [Epoch 425/1000] Train SV: 2.9e-03 conc: 1.0e-02 | Val SV: 5.8e-04 conc: 5.9e-03
# [Epoch 426/1000] Train SV: 2.9e-03 conc: 9.4e-03 | Val SV: 5.1e-04 conc: 6.8e-03
# [Epoch 427/1000] Train SV: 2.8e-03 conc: 8.9e-03 | Val SV: 6.2e-04 conc: 6.2e-03
# [Epoch 428/1000] Train SV: 3.0e-03 conc: 9.4e-03 | Val SV: 5.3e-04 conc: 5.4e-03
# Early stopping triggered. Restoring best weights.
# Model weights saved to 'model_name_0.weights.h5' and config saved to 'model_name_0.config.json'.
# [Epoch 1/1000] Train SV: 9.9e-02 conc: 1.6e-01 | Val SV: 1.4e-02 conc: 5.1e-02
# [Epoch 2/1000] Train SV: 1.0e-02 conc: 3.3e-02 | Val SV: 2.8e-03 conc: 3.1e-02
# [Epoch 3/1000] Train SV: 3.9e-03 conc: 1.9e-02 | Val SV: 9.2e-04 conc: 7.7e-03
# [Epoch 4/1000] Train SV: 3.4e-03 conc: 2.6e-02 | Val SV: 1.4e-03 conc: 1.3e-02
# [Epoch 5/1000] Train SV: 2.4e-03 conc: 1.5e-02 | Val SV: 5.5e-04 conc: 3.3e-02
# [Epoch 6/1000] Train SV: 1.8e-03 conc: 2.8e-02 | Val SV: 6.4e-04 conc: 2.9e-02
# [Epoch 7/1000] Train SV: 1.7e-03 conc: 3.5e-02 | Val SV: 5.8e-04 conc: 2.1e-02
# [Epoch 8/1000] Train SV: 1.3e-03 conc: 1.4e-02 | Val SV: 4.2e-04 conc: 8.9e-03
# [Epoch 9/1000] Train SV: 1.7e-03 conc: 3.3e-02 | Val SV: 2.4e-03 conc: 6.2e-02
# [Epoch 10/1000] Train SV: 2.3e-03 conc: 3.7e-02 | Val SV: 1.3e-03 conc: 2.5e-02
# [Epoch 11/1000] Train SV: 1.5e-03 conc: 1.7e-02 | Val SV: 9.0e-04 conc: 1.5e-02
# [Epoch 12/1000] Train SV: 1.4e-03 conc: 1.5e-02 | Val SV: 7.9e-04 conc: 1.3e-02
# [Epoch 13/1000] Train SV: 9.2e-04 conc: 1.1e-02 | Val SV: 5.3e-04 conc: 1.2e-02
# [Epoch 14/1000] Train SV: 8.2e-04 conc: 1.5e-02 | Val SV: 3.4e-04 conc: 6.2e-03
# [Epoch 15/1000] Train SV: 7.2e-04 conc: 1.2e-02 | Val SV: 3.1e-04 conc: 7.8e-03
# [Epoch 16/1000] Train SV: 7.6e-04 conc: 1.5e-02 | Val SV: 7.5e-04 conc: 5.7e-03
# [Epoch 17/1000] Train SV: 7.3e-04 conc: 1.0e-02 | Val SV: 3.5e-04 conc: 7.6e-03
# [Epoch 18/1000] Train SV: 6.4e-04 conc: 9.5e-03 | Val SV: 2.8e-04 conc: 5.9e-03
# [Epoch 19/1000] Train SV: 6.0e-04 conc: 8.5e-03 | Val SV: 3.3e-04 conc: 1.2e-02
# [Epoch 20/1000] Train SV: 5.9e-04 conc: 1.3e-02 | Val SV: 4.1e-04 conc: 1.3e-02
# [Epoch 21/1000] Train SV: 6.6e-04 conc: 2.4e-02 | Val SV: 3.3e-04 conc: 3.4e-02
# [Epoch 22/1000] Train SV: 6.8e-04 conc: 2.0e-02 | Val SV: 3.4e-04 conc: 8.4e-03
# [Epoch 23/1000] Train SV: 5.9e-04 conc: 1.4e-02 | Val SV: 3.5e-04 conc: 8.3e-03
# [Epoch 24/1000] Train SV: 5.3e-04 conc: 1.2e-02 | Val SV: 2.8e-04 conc: 1.4e-02
# [Epoch 25/1000] Train SV: 4.7e-04 conc: 1.1e-02 | Val SV: 2.2e-04 conc: 8.8e-03
# [Epoch 26/1000] Train SV: 4.3e-04 conc: 1.0e-02 | Val SV: 2.2e-04 conc: 4.0e-03
# [Epoch 27/1000] Train SV: 4.4e-04 conc: 1.1e-02 | Val SV: 2.8e-04 conc: 1.0e-02
# [Epoch 28/1000] Train SV: 4.3e-04 conc: 1.0e-02 | Val SV: 2.2e-04 conc: 7.2e-03
# [Epoch 29/1000] Train SV: 3.7e-04 conc: 6.7e-03 | Val SV: 2.0e-04 conc: 4.0e-03
# [Epoch 30/1000] Train SV: 3.7e-04 conc: 6.1e-03 | Val SV: 2.3e-04 conc: 4.8e-03
# [Epoch 31/1000] Train SV: 3.7e-04 conc: 9.6e-03 | Val SV: 1.9e-04 conc: 7.0e-03
# [Epoch 32/1000] Train SV: 3.4e-04 conc: 6.7e-03 | Val SV: 1.8e-04 conc: 5.0e-03
# [Epoch 33/1000] Train SV: 3.1e-04 conc: 6.7e-03 | Val SV: 1.7e-04 conc: 4.5e-03
# [Epoch 34/1000] Train SV: 3.2e-04 conc: 8.8e-03 | Val SV: 1.7e-04 conc: 5.7e-03
# [Epoch 35/1000] Train SV: 3.0e-04 conc: 6.4e-03 | Val SV: 1.7e-04 conc: 5.0e-03
# [Epoch 36/1000] Train SV: 2.9e-04 conc: 8.5e-03 | Val SV: 1.8e-04 conc: 1.0e-02
# [Epoch 37/1000] Train SV: 2.9e-04 conc: 7.2e-03 | Val SV: 1.6e-04 conc: 5.2e-03
# [Epoch 38/1000] Train SV: 2.7e-04 conc: 6.1e-03 | Val SV: 1.7e-04 conc: 3.9e-03
# [Epoch 39/1000] Train SV: 2.6e-04 conc: 5.1e-03 | Val SV: 1.5e-04 conc: 5.2e-03
# [Epoch 40/1000] Train SV: 2.5e-04 conc: 5.3e-03 | Val SV: 1.4e-04 conc: 4.8e-03
# [Epoch 41/1000] Train SV: 2.5e-04 conc: 5.6e-03 | Val SV: 1.4e-04 conc: 5.3e-03
# [Epoch 42/1000] Train SV: 2.5e-04 conc: 5.1e-03 | Val SV: 1.4e-04 conc: 3.9e-03
# [Epoch 43/1000] Train SV: 2.4e-04 conc: 5.7e-03 | Val SV: 1.7e-04 conc: 6.0e-03
# [Epoch 44/1000] Train SV: 2.5e-04 conc: 5.6e-03 | Val SV: 1.4e-04 conc: 4.7e-03
# [Epoch 45/1000] Train SV: 2.4e-04 conc: 5.2e-03 | Val SV: 1.3e-04 conc: 3.5e-03
# [Epoch 46/1000] Train SV: 2.3e-04 conc: 5.3e-03 | Val SV: 1.3e-04 conc: 5.0e-03
# [Epoch 47/1000] Train SV: 2.3e-04 conc: 5.2e-03 | Val SV: 1.3e-04 conc: 5.2e-03
# [Epoch 48/1000] Train SV: 2.6e-04 conc: 8.7e-03 | Val SV: 2.5e-04 conc: 5.3e-03
# [Epoch 49/1000] Train SV: 2.4e-04 conc: 6.7e-03 | Val SV: 1.3e-04 conc: 9.1e-03
# [Epoch 50/1000] Train SV: 2.2e-04 conc: 6.5e-03 | Val SV: 1.3e-04 conc: 4.7e-03
# [Epoch 51/1000] Train SV: 2.1e-04 conc: 6.3e-03 | Val SV: 1.3e-04 conc: 4.7e-03
# [Epoch 52/1000] Train SV: 2.1e-04 conc: 5.4e-03 | Val SV: 1.5e-04 conc: 3.6e-03
# [Epoch 53/1000] Train SV: 2.1e-04 conc: 4.5e-03 | Val SV: 1.2e-04 conc: 5.8e-03
# [Epoch 54/1000] Train SV: 2.0e-04 conc: 5.4e-03 | Val SV: 1.2e-04 conc: 3.2e-03
# [Epoch 55/1000] Train SV: 1.9e-04 conc: 4.6e-03 | Val SV: 1.1e-04 conc: 3.3e-03
# [Epoch 56/1000] Train SV: 1.9e-04 conc: 4.5e-03 | Val SV: 1.1e-04 conc: 4.0e-03
# [Epoch 57/1000] Train SV: 1.9e-04 conc: 4.8e-03 | Val SV: 1.0e-04 conc: 5.3e-03
# [Epoch 58/1000] Train SV: 1.9e-04 conc: 6.0e-03 | Val SV: 1.4e-04 conc: 5.4e-03
# [Epoch 59/1000] Train SV: 1.9e-04 conc: 5.8e-03 | Val SV: 1.2e-04 conc: 4.5e-03
# [Epoch 60/1000] Train SV: 1.9e-04 conc: 6.0e-03 | Val SV: 1.1e-04 conc: 3.7e-03
# [Epoch 61/1000] Train SV: 1.9e-04 conc: 7.0e-03 | Val SV: 1.3e-04 conc: 7.7e-03
# [Epoch 62/1000] Train SV: 1.9e-04 conc: 6.8e-03 | Val SV: 1.1e-04 conc: 4.6e-03
# [Epoch 63/1000] Train SV: 1.7e-04 conc: 4.7e-03 | Val SV: 1.0e-04 conc: 4.0e-03
# [Epoch 64/1000] Train SV: 1.7e-04 conc: 4.0e-03 | Val SV: 1.0e-04 conc: 3.8e-03
# [Epoch 65/1000] Train SV: 1.6e-04 conc: 4.7e-03 | Val SV: 1.1e-04 conc: 4.9e-03
# [Epoch 66/1000] Train SV: 1.7e-04 conc: 5.3e-03 | Val SV: 9.4e-05 conc: 4.1e-03
# [Epoch 67/1000] Train SV: 1.6e-04 conc: 4.7e-03 | Val SV: 1.1e-04 conc: 5.7e-03
# [Epoch 68/1000] Train SV: 1.6e-04 conc: 5.2e-03 | Val SV: 9.4e-05 conc: 4.2e-03
# [Epoch 69/1000] Train SV: 1.5e-04 conc: 4.0e-03 | Val SV: 9.2e-05 conc: 4.4e-03
# [Epoch 70/1000] Train SV: 1.5e-04 conc: 4.5e-03 | Val SV: 8.5e-05 conc: 3.8e-03
# [Epoch 71/1000] Train SV: 1.5e-04 conc: 4.7e-03 | Val SV: 8.7e-05 conc: 3.6e-03
# [Epoch 72/1000] Train SV: 1.4e-04 conc: 4.1e-03 | Val SV: 1.1e-04 conc: 4.8e-03
# [Epoch 73/1000] Train SV: 1.5e-04 conc: 4.8e-03 | Val SV: 1.1e-04 conc: 4.4e-03
# [Epoch 74/1000] Train SV: 1.5e-04 conc: 5.5e-03 | Val SV: 8.8e-05 conc: 5.9e-03
# [Epoch 75/1000] Train SV: 1.4e-04 conc: 4.4e-03 | Val SV: 8.4e-05 conc: 3.5e-03
# [Epoch 76/1000] Train SV: 1.4e-04 conc: 3.9e-03 | Val SV: 9.0e-05 conc: 3.4e-03
# [Epoch 77/1000] Train SV: 1.4e-04 conc: 3.4e-03 | Val SV: 7.7e-05 conc: 3.3e-03
# [Epoch 78/1000] Train SV: 1.3e-04 conc: 3.7e-03 | Val SV: 7.9e-05 conc: 3.1e-03
# [Epoch 79/1000] Train SV: 1.3e-04 conc: 3.5e-03 | Val SV: 7.7e-05 conc: 3.3e-03
# [Epoch 80/1000] Train SV: 1.3e-04 conc: 3.7e-03 | Val SV: 7.8e-05 conc: 3.2e-03
# [Epoch 81/1000] Train SV: 1.3e-04 conc: 3.7e-03 | Val SV: 8.1e-05 conc: 3.4e-03
# [Epoch 82/1000] Train SV: 1.2e-04 conc: 4.1e-03 | Val SV: 8.2e-05 conc: 2.9e-03
# [Epoch 83/1000] Train SV: 1.3e-04 conc: 3.6e-03 | Val SV: 7.5e-05 conc: 3.2e-03
# [Epoch 84/1000] Train SV: 1.2e-04 conc: 4.2e-03 | Val SV: 7.7e-05 conc: 3.0e-03
# [Epoch 85/1000] Train SV: 1.2e-04 conc: 4.0e-03 | Val SV: 7.7e-05 conc: 4.1e-03
# [Epoch 86/1000] Train SV: 1.2e-04 conc: 4.7e-03 | Val SV: 7.9e-05 conc: 3.4e-03
# [Epoch 87/1000] Train SV: 1.2e-04 conc: 4.1e-03 | Val SV: 7.9e-05 conc: 3.8e-03
# [Epoch 88/1000] Train SV: 1.2e-04 conc: 3.8e-03 | Val SV: 6.8e-05 conc: 3.3e-03
# [Epoch 89/1000] Train SV: 1.1e-04 conc: 3.5e-03 | Val SV: 7.4e-05 conc: 3.7e-03
# [Epoch 90/1000] Train SV: 1.1e-04 conc: 3.7e-03 | Val SV: 7.1e-05 conc: 3.8e-03
# [Epoch 91/1000] Train SV: 1.1e-04 conc: 3.4e-03 | Val SV: 6.9e-05 conc: 3.3e-03
# [Epoch 92/1000] Train SV: 1.2e-04 conc: 3.7e-03 | Val SV: 8.5e-05 conc: 4.6e-03
# [Epoch 93/1000] Train SV: 1.1e-04 conc: 3.7e-03 | Val SV: 6.9e-05 conc: 3.1e-03
# [Epoch 94/1000] Train SV: 1.1e-04 conc: 3.3e-03 | Val SV: 6.4e-05 conc: 3.3e-03
# [Epoch 95/1000] Train SV: 1.1e-04 conc: 3.8e-03 | Val SV: 6.8e-05 conc: 3.2e-03
# [Epoch 96/1000] Train SV: 1.1e-04 conc: 3.6e-03 | Val SV: 6.8e-05 conc: 4.4e-03
# [Epoch 97/1000] Train SV: 1.1e-04 conc: 4.2e-03 | Val SV: 7.0e-05 conc: 4.5e-03
# [Epoch 98/1000] Train SV: 1.1e-04 conc: 3.9e-03 | Val SV: 6.8e-05 conc: 3.2e-03
# [Epoch 99/1000] Train SV: 1.1e-04 conc: 3.7e-03 | Val SV: 6.5e-05 conc: 3.5e-03
# [Epoch 100/1000] Train SV: 1.0e-04 conc: 3.4e-03 | Val SV: 6.4e-05 conc: 4.0e-03
# [Epoch 101/1000] Train SV: 1.0e-04 conc: 3.7e-03 | Val SV: 6.6e-05 conc: 3.1e-03
# [Epoch 102/1000] Train SV: 1.0e-04 conc: 3.4e-03 | Val SV: 6.2e-05 conc: 3.0e-03
# [Epoch 103/1000] Train SV: 1.0e-04 conc: 3.6e-03 | Val SV: 6.3e-05 conc: 3.3e-03
# [Epoch 104/1000] Train SV: 9.9e-05 conc: 3.4e-03 | Val SV: 6.5e-05 conc: 3.9e-03
# [Epoch 105/1000] Train SV: 9.7e-05 conc: 3.3e-03 | Val SV: 6.0e-05 conc: 2.9e-03
# [Epoch 106/1000] Train SV: 1.0e-04 conc: 3.3e-03 | Val SV: 6.8e-05 conc: 3.3e-03
# [Epoch 107/1000] Train SV: 9.6e-05 conc: 3.2e-03 | Val SV: 6.2e-05 conc: 4.0e-03
# [Epoch 108/1000] Train SV: 9.7e-05 conc: 3.4e-03 | Val SV: 6.2e-05 conc: 3.0e-03
# [Epoch 109/1000] Train SV: 9.5e-05 conc: 3.4e-03 | Val SV: 6.2e-05 conc: 3.3e-03
# [Epoch 110/1000] Train SV: 9.8e-05 conc: 3.5e-03 | Val SV: 5.9e-05 conc: 3.0e-03
# [Epoch 111/1000] Train SV: 9.5e-05 conc: 3.5e-03 | Val SV: 6.0e-05 conc: 3.1e-03
# [Epoch 112/1000] Train SV: 9.3e-05 conc: 3.0e-03 | Val SV: 6.0e-05 conc: 4.0e-03
# [Epoch 113/1000] Train SV: 9.4e-05 conc: 3.6e-03 | Val SV: 5.8e-05 conc: 3.3e-03
# [Epoch 114/1000] Train SV: 9.1e-05 conc: 3.3e-03 | Val SV: 5.7e-05 conc: 3.9e-03
# [Epoch 115/1000] Train SV: 9.1e-05 conc: 3.3e-03 | Val SV: 5.6e-05 conc: 3.2e-03
# [Epoch 116/1000] Train SV: 8.9e-05 conc: 3.0e-03 | Val SV: 5.6e-05 conc: 3.0e-03
# [Epoch 117/1000] Train SV: 8.7e-05 conc: 3.1e-03 | Val SV: 5.5e-05 conc: 3.7e-03
# [Epoch 118/1000] Train SV: 8.8e-05 conc: 3.2e-03 | Val SV: 5.4e-05 conc: 2.8e-03
# [Epoch 119/1000] Train SV: 8.7e-05 conc: 3.0e-03 | Val SV: 5.7e-05 conc: 2.9e-03
# [Epoch 120/1000] Train SV: 8.8e-05 conc: 2.8e-03 | Val SV: 5.5e-05 conc: 2.8e-03
# [Epoch 121/1000] Train SV: 8.9e-05 conc: 3.3e-03 | Val SV: 6.1e-05 conc: 3.9e-03
# [Epoch 122/1000] Train SV: 8.8e-05 conc: 3.3e-03 | Val SV: 5.4e-05 conc: 2.9e-03
# [Epoch 123/1000] Train SV: 8.5e-05 conc: 3.1e-03 | Val SV: 5.4e-05 conc: 3.3e-03
# [Epoch 124/1000] Train SV: 8.4e-05 conc: 2.9e-03 | Val SV: 5.3e-05 conc: 2.8e-03
# [Epoch 125/1000] Train SV: 8.2e-05 conc: 2.9e-03 | Val SV: 5.3e-05 conc: 3.2e-03
# [Epoch 126/1000] Train SV: 8.2e-05 conc: 2.9e-03 | Val SV: 5.1e-05 conc: 2.9e-03
# [Epoch 127/1000] Train SV: 8.0e-05 conc: 3.2e-03 | Val SV: 5.0e-05 conc: 2.7e-03
# [Epoch 128/1000] Train SV: 7.8e-05 conc: 3.2e-03 | Val SV: 5.0e-05 conc: 2.8e-03
# [Epoch 129/1000] Train SV: 8.0e-05 conc: 3.6e-03 | Val SV: 5.4e-05 conc: 3.3e-03
# [Epoch 130/1000] Train SV: 8.0e-05 conc: 3.1e-03 | Val SV: 5.0e-05 conc: 2.8e-03
# [Epoch 131/1000] Train SV: 7.9e-05 conc: 2.9e-03 | Val SV: 4.9e-05 conc: 2.6e-03
# [Epoch 132/1000] Train SV: 7.8e-05 conc: 2.6e-03 | Val SV: 5.2e-05 conc: 3.4e-03
# [Epoch 133/1000] Train SV: 7.9e-05 conc: 2.9e-03 | Val SV: 4.8e-05 conc: 2.8e-03
# [Epoch 134/1000] Train SV: 7.7e-05 conc: 3.0e-03 | Val SV: 5.0e-05 conc: 3.6e-03
# [Epoch 135/1000] Train SV: 7.7e-05 conc: 2.8e-03 | Val SV: 4.9e-05 conc: 2.7e-03
# [Epoch 136/1000] Train SV: 7.5e-05 conc: 2.7e-03 | Val SV: 4.8e-05 conc: 2.8e-03
# [Epoch 137/1000] Train SV: 7.7e-05 conc: 2.7e-03 | Val SV: 4.8e-05 conc: 2.8e-03
# [Epoch 138/1000] Train SV: 7.5e-05 conc: 3.3e-03 | Val SV: 4.7e-05 conc: 3.6e-03
# [Epoch 139/1000] Train SV: 7.5e-05 conc: 3.0e-03 | Val SV: 4.9e-05 conc: 3.1e-03
# [Epoch 140/1000] Train SV: 7.7e-05 conc: 2.8e-03 | Val SV: 4.7e-05 conc: 3.2e-03
# [Epoch 141/1000] Train SV: 7.4e-05 conc: 2.8e-03 | Val SV: 4.7e-05 conc: 2.7e-03
# [Epoch 142/1000] Train SV: 7.3e-05 conc: 2.7e-03 | Val SV: 4.7e-05 conc: 2.9e-03
# [Epoch 143/1000] Train SV: 7.5e-05 conc: 2.6e-03 | Val SV: 4.7e-05 conc: 2.7e-03
# [Epoch 144/1000] Train SV: 7.4e-05 conc: 2.8e-03 | Val SV: 4.7e-05 conc: 3.0e-03
# [Epoch 145/1000] Train SV: 7.2e-05 conc: 2.9e-03 | Val SV: 4.6e-05 conc: 3.2e-03
# [Epoch 146/1000] Train SV: 7.1e-05 conc: 2.6e-03 | Val SV: 4.8e-05 conc: 2.8e-03
# [Epoch 147/1000] Train SV: 7.3e-05 conc: 2.8e-03 | Val SV: 4.7e-05 conc: 2.8e-03
# [Epoch 148/1000] Train SV: 7.2e-05 conc: 2.7e-03 | Val SV: 4.5e-05 conc: 2.9e-03
# [Epoch 149/1000] Train SV: 7.1e-05 conc: 2.6e-03 | Val SV: 4.6e-05 conc: 3.5e-03
# [Epoch 150/1000] Train SV: 7.0e-05 conc: 2.8e-03 | Val SV: 4.5e-05 conc: 3.5e-03
# [Epoch 151/1000] Train SV: 6.9e-05 conc: 2.7e-03 | Val SV: 4.4e-05 conc: 3.0e-03
# [Epoch 152/1000] Train SV: 6.9e-05 conc: 2.8e-03 | Val SV: 4.5e-05 conc: 2.7e-03
# [Epoch 153/1000] Train SV: 6.9e-05 conc: 2.8e-03 | Val SV: 4.4e-05 conc: 2.9e-03
# [Epoch 154/1000] Train SV: 6.8e-05 conc: 2.8e-03 | Val SV: 4.4e-05 conc: 2.9e-03
# [Epoch 155/1000] Train SV: 6.8e-05 conc: 3.1e-03 | Val SV: 4.3e-05 conc: 3.1e-03
# [Epoch 156/1000] Train SV: 6.7e-05 conc: 2.7e-03 | Val SV: 4.3e-05 conc: 2.7e-03
# [Epoch 157/1000] Train SV: 6.8e-05 conc: 3.1e-03 | Val SV: 4.4e-05 conc: 4.2e-03
# [Epoch 158/1000] Train SV: 6.9e-05 conc: 3.7e-03 | Val SV: 4.7e-05 conc: 4.2e-03
# [Epoch 159/1000] Train SV: 6.7e-05 conc: 3.0e-03 | Val SV: 4.3e-05 conc: 2.7e-03
# [Epoch 160/1000] Train SV: 6.6e-05 conc: 2.6e-03 | Val SV: 4.2e-05 conc: 3.2e-03
# [Epoch 161/1000] Train SV: 6.5e-05 conc: 2.7e-03 | Val SV: 4.1e-05 conc: 2.9e-03
# [Epoch 162/1000] Train SV: 6.5e-05 conc: 2.5e-03 | Val SV: 4.1e-05 conc: 2.9e-03
# [Epoch 163/1000] Train SV: 6.4e-05 conc: 2.6e-03 | Val SV: 4.2e-05 conc: 2.8e-03
# [Epoch 164/1000] Train SV: 6.5e-05 conc: 2.7e-03 | Val SV: 4.1e-05 conc: 2.8e-03
# [Epoch 165/1000] Train SV: 6.3e-05 conc: 2.9e-03 | Val SV: 4.1e-05 conc: 2.7e-03
# [Epoch 166/1000] Train SV: 6.3e-05 conc: 2.5e-03 | Val SV: 4.0e-05 conc: 2.6e-03
# [Epoch 167/1000] Train SV: 6.3e-05 conc: 2.7e-03 | Val SV: 4.2e-05 conc: 2.8e-03
# [Epoch 168/1000] Train SV: 6.4e-05 conc: 2.5e-03 | Val SV: 4.1e-05 conc: 2.8e-03
# [Epoch 169/1000] Train SV: 6.4e-05 conc: 2.5e-03 | Val SV: 4.0e-05 conc: 2.6e-03
# [Epoch 170/1000] Train SV: 6.3e-05 conc: 2.5e-03 | Val SV: 4.0e-05 conc: 2.6e-03
# [Epoch 171/1000] Train SV: 6.3e-05 conc: 2.6e-03 | Val SV: 4.0e-05 conc: 2.9e-03
# [Epoch 172/1000] Train SV: 6.1e-05 conc: 2.6e-03 | Val SV: 3.9e-05 conc: 2.9e-03
# [Epoch 173/1000] Train SV: 6.1e-05 conc: 2.4e-03 | Val SV: 3.8e-05 conc: 2.6e-03
# [Epoch 174/1000] Train SV: 6.0e-05 conc: 2.6e-03 | Val SV: 3.9e-05 conc: 2.4e-03
# [Epoch 175/1000] Train SV: 6.1e-05 conc: 2.5e-03 | Val SV: 3.9e-05 conc: 2.8e-03
# [Epoch 176/1000] Train SV: 6.2e-05 conc: 2.4e-03 | Val SV: 4.0e-05 conc: 3.5e-03
# [Epoch 177/1000] Train SV: 6.2e-05 conc: 2.4e-03 | Val SV: 3.9e-05 conc: 2.9e-03
# [Epoch 178/1000] Train SV: 6.1e-05 conc: 2.4e-03 | Val SV: 3.9e-05 conc: 2.5e-03
# [Epoch 179/1000] Train SV: 6.0e-05 conc: 2.4e-03 | Val SV: 3.8e-05 conc: 2.4e-03
# [Epoch 180/1000] Train SV: 6.1e-05 conc: 2.4e-03 | Val SV: 3.8e-05 conc: 3.0e-03
# [Epoch 181/1000] Train SV: 6.0e-05 conc: 2.5e-03 | Val SV: 3.9e-05 conc: 2.9e-03
# [Epoch 182/1000] Train SV: 5.9e-05 conc: 2.4e-03 | Val SV: 3.7e-05 conc: 2.8e-03
# [Epoch 183/1000] Train SV: 5.7e-05 conc: 2.1e-03 | Val SV: 3.8e-05 conc: 2.6e-03
# [Epoch 184/1000] Train SV: 5.7e-05 conc: 2.2e-03 | Val SV: 3.7e-05 conc: 2.7e-03
# [Epoch 185/1000] Train SV: 5.8e-05 conc: 2.8e-03 | Val SV: 3.8e-05 conc: 2.6e-03
# [Epoch 186/1000] Train SV: 5.9e-05 conc: 2.4e-03 | Val SV: 3.7e-05 conc: 2.5e-03
# [Epoch 187/1000] Train SV: 5.7e-05 conc: 2.0e-03 | Val SV: 3.6e-05 conc: 2.5e-03
# [Epoch 188/1000] Train SV: 5.6e-05 conc: 2.2e-03 | Val SV: 3.6e-05 conc: 3.2e-03
# [Epoch 189/1000] Train SV: 5.7e-05 conc: 2.0e-03 | Val SV: 3.6e-05 conc: 2.6e-03
# [Epoch 190/1000] Train SV: 5.5e-05 conc: 2.2e-03 | Val SV: 3.6e-05 conc: 2.8e-03
# [Epoch 191/1000] Train SV: 5.6e-05 conc: 2.4e-03 | Val SV: 3.6e-05 conc: 2.6e-03
# [Epoch 192/1000] Train SV: 5.7e-05 conc: 2.5e-03 | Val SV: 3.6e-05 conc: 2.5e-03
# [Epoch 193/1000] Train SV: 5.6e-05 conc: 2.5e-03 | Val SV: 3.7e-05 conc: 3.8e-03
# [Epoch 194/1000] Train SV: 5.7e-05 conc: 2.3e-03 | Val SV: 3.7e-05 conc: 3.1e-03
# [Epoch 195/1000] Train SV: 5.5e-05 conc: 2.4e-03 | Val SV: 3.5e-05 conc: 2.6e-03
# [Epoch 196/1000] Train SV: 5.5e-05 conc: 2.1e-03 | Val SV: 3.5e-05 conc: 2.7e-03
# [Epoch 197/1000] Train SV: 5.6e-05 conc: 1.9e-03 | Val SV: 3.6e-05 conc: 3.8e-03
# [Epoch 198/1000] Train SV: 5.5e-05 conc: 2.6e-03 | Val SV: 3.6e-05 conc: 2.9e-03
# [Epoch 199/1000] Train SV: 5.6e-05 conc: 2.3e-03 | Val SV: 3.6e-05 conc: 3.3e-03
# [Epoch 200/1000] Train SV: 5.5e-05 conc: 2.1e-03 | Val SV: 3.5e-05 conc: 2.6e-03
# [Epoch 201/1000] Train SV: 5.4e-05 conc: 1.9e-03 | Val SV: 3.4e-05 conc: 2.7e-03
# [Epoch 202/1000] Train SV: 5.4e-05 conc: 2.7e-03 | Val SV: 3.5e-05 conc: 3.1e-03
# [Epoch 203/1000] Train SV: 5.4e-05 conc: 2.2e-03 | Val SV: 3.5e-05 conc: 2.9e-03
# [Epoch 204/1000] Train SV: 5.4e-05 conc: 2.1e-03 | Val SV: 3.4e-05 conc: 2.7e-03
# [Epoch 205/1000] Train SV: 5.3e-05 conc: 2.3e-03 | Val SV: 3.3e-05 conc: 2.5e-03
# [Epoch 206/1000] Train SV: 5.2e-05 conc: 2.1e-03 | Val SV: 3.4e-05 conc: 3.0e-03
# [Epoch 207/1000] Train SV: 5.2e-05 conc: 2.1e-03 | Val SV: 3.5e-05 conc: 3.3e-03
# [Epoch 208/1000] Train SV: 5.3e-05 conc: 2.5e-03 | Val SV: 3.5e-05 conc: 3.0e-03
# [Epoch 209/1000] Train SV: 5.2e-05 conc: 2.2e-03 | Val SV: 3.3e-05 conc: 2.7e-03
# [Epoch 210/1000] Train SV: 5.2e-05 conc: 1.9e-03 | Val SV: 3.4e-05 conc: 3.9e-03
# [Epoch 211/1000] Train SV: 5.2e-05 conc: 2.2e-03 | Val SV: 3.3e-05 conc: 2.5e-03
# [Epoch 212/1000] Train SV: 5.1e-05 conc: 2.0e-03 | Val SV: 3.3e-05 conc: 3.0e-03
# [Epoch 213/1000] Train SV: 5.0e-05 conc: 2.1e-03 | Val SV: 3.3e-05 conc: 2.6e-03
# [Epoch 214/1000] Train SV: 5.1e-05 conc: 2.0e-03 | Val SV: 3.4e-05 conc: 2.9e-03
# [Epoch 215/1000] Train SV: 5.1e-05 conc: 2.2e-03 | Val SV: 3.4e-05 conc: 2.9e-03
# [Epoch 216/1000] Train SV: 5.2e-05 conc: 1.9e-03 | Val SV: 3.2e-05 conc: 3.1e-03
# [Epoch 217/1000] Train SV: 5.0e-05 conc: 2.0e-03 | Val SV: 3.2e-05 conc: 2.6e-03
# [Epoch 218/1000] Train SV: 5.1e-05 conc: 2.0e-03 | Val SV: 3.3e-05 conc: 2.7e-03
# [Epoch 219/1000] Train SV: 5.1e-05 conc: 2.1e-03 | Val SV: 3.4e-05 conc: 3.1e-03
# [Epoch 220/1000] Train SV: 5.1e-05 conc: 2.3e-03 | Val SV: 3.3e-05 conc: 3.1e-03
# [Epoch 221/1000] Train SV: 4.9e-05 conc: 2.1e-03 | Val SV: 3.2e-05 conc: 2.7e-03
# [Epoch 222/1000] Train SV: 4.9e-05 conc: 2.1e-03 | Val SV: 3.2e-05 conc: 2.9e-03
# [Epoch 223/1000] Train SV: 5.0e-05 conc: 2.2e-03 | Val SV: 3.2e-05 conc: 3.2e-03
# [Epoch 224/1000] Train SV: 5.0e-05 conc: 2.0e-03 | Val SV: 3.2e-05 conc: 3.4e-03
# Early stopping triggered. Restoring best weights.
# Model weights saved to 'model_name_1.weights.h5' and config saved to 'model_name_1.config.json'.
# [Epoch 1/1000] Train SV: 1.3e-03 conc: 1.1e-02 | Val SV: 9.0e-04 conc: 6.2e-03
# [Epoch 2/1000] Train SV: 4.8e-04 conc: 7.6e-03 | Val SV: 1.5e-04 conc: 5.6e-03
# [Epoch 3/1000] Train SV: 1.6e-04 conc: 5.5e-03 | Val SV: 8.9e-05 conc: 4.6e-03
# [Epoch 4/1000] Train SV: 1.1e-04 conc: 4.4e-03 | Val SV: 5.1e-05 conc: 4.8e-03
# [Epoch 5/1000] Train SV: 8.2e-05 conc: 4.0e-03 | Val SV: 5.6e-05 conc: 4.2e-03
# [Epoch 6/1000] Train SV: 7.3e-05 conc: 4.0e-03 | Val SV: 6.3e-05 conc: 4.4e-03
# [Epoch 7/1000] Train SV: 6.8e-05 conc: 3.6e-03 | Val SV: 4.1e-05 conc: 3.4e-03
# [Epoch 8/1000] Train SV: 5.3e-05 conc: 3.9e-03 | Val SV: 3.3e-05 conc: 3.1e-03
# [Epoch 9/1000] Train SV: 4.9e-05 conc: 3.8e-03 | Val SV: 3.5e-05 conc: 5.3e-03
# [Epoch 10/1000] Train SV: 4.7e-05 conc: 3.7e-03 | Val SV: 3.6e-05 conc: 3.5e-03
# [Epoch 11/1000] Train SV: 4.4e-05 conc: 4.0e-03 | Val SV: 3.9e-05 conc: 5.4e-03
# [Epoch 12/1000] Train SV: 4.3e-05 conc: 4.2e-03 | Val SV: 3.2e-05 conc: 4.9e-03
# [Epoch 13/1000] Train SV: 4.0e-05 conc: 3.0e-03 | Val SV: 3.2e-05 conc: 5.5e-03
# [Epoch 14/1000] Train SV: 5.1e-05 conc: 4.2e-03 | Val SV: 4.6e-05 conc: 3.0e-03
# [Epoch 15/1000] Train SV: 4.6e-05 conc: 3.1e-03 | Val SV: 3.4e-05 conc: 3.3e-03
# [Epoch 16/1000] Train SV: 4.0e-05 conc: 3.7e-03 | Val SV: 2.9e-05 conc: 2.7e-03
# [Epoch 17/1000] Train SV: 3.4e-05 conc: 3.1e-03 | Val SV: 2.5e-05 conc: 3.1e-03
# [Epoch 18/1000] Train SV: 3.2e-05 conc: 3.1e-03 | Val SV: 2.3e-05 conc: 3.0e-03
# [Epoch 19/1000] Train SV: 3.1e-05 conc: 3.2e-03 | Val SV: 2.4e-05 conc: 2.9e-03
# [Epoch 20/1000] Train SV: 3.1e-05 conc: 2.8e-03 | Val SV: 2.4e-05 conc: 3.4e-03
# [Epoch 21/1000] Train SV: 3.0e-05 conc: 2.7e-03 | Val SV: 2.1e-05 conc: 2.6e-03
# [Epoch 22/1000] Train SV: 2.7e-05 conc: 2.9e-03 | Val SV: 2.1e-05 conc: 4.1e-03
# [Epoch 23/1000] Train SV: 2.9e-05 conc: 3.6e-03 | Val SV: 2.2e-05 conc: 4.5e-03
# [Epoch 24/1000] Train SV: 2.7e-05 conc: 3.3e-03 | Val SV: 2.0e-05 conc: 2.9e-03
# [Epoch 25/1000] Train SV: 2.6e-05 conc: 2.8e-03 | Val SV: 1.8e-05 conc: 3.2e-03
# [Epoch 26/1000] Train SV: 2.5e-05 conc: 3.4e-03 | Val SV: 1.8e-05 conc: 2.8e-03
# [Epoch 27/1000] Train SV: 2.3e-05 conc: 2.8e-03 | Val SV: 1.7e-05 conc: 2.9e-03
# [Epoch 28/1000] Train SV: 2.2e-05 conc: 2.9e-03 | Val SV: 1.7e-05 conc: 2.7e-03
# [Epoch 29/1000] Train SV: 2.3e-05 conc: 2.8e-03 | Val SV: 1.8e-05 conc: 4.1e-03
# [Epoch 30/1000] Train SV: 2.2e-05 conc: 2.3e-03 | Val SV: 1.7e-05 conc: 3.0e-03
# [Epoch 31/1000] Train SV: 2.1e-05 conc: 2.3e-03 | Val SV: 1.9e-05 conc: 2.6e-03
# [Epoch 32/1000] Train SV: 2.1e-05 conc: 2.2e-03 | Val SV: 1.5e-05 conc: 3.0e-03
# [Epoch 33/1000] Train SV: 2.0e-05 conc: 2.7e-03 | Val SV: 1.5e-05 conc: 2.6e-03
# [Epoch 34/1000] Train SV: 2.0e-05 conc: 2.5e-03 | Val SV: 1.5e-05 conc: 3.0e-03
# [Epoch 35/1000] Train SV: 1.9e-05 conc: 2.7e-03 | Val SV: 1.5e-05 conc: 2.7e-03
# [Epoch 36/1000] Train SV: 2.0e-05 conc: 2.8e-03 | Val SV: 1.5e-05 conc: 3.3e-03
# [Epoch 37/1000] Train SV: 1.8e-05 conc: 2.4e-03 | Val SV: 1.4e-05 conc: 3.5e-03
# [Epoch 38/1000] Train SV: 1.8e-05 conc: 2.3e-03 | Val SV: 1.4e-05 conc: 2.5e-03
# [Epoch 39/1000] Train SV: 1.8e-05 conc: 2.2e-03 | Val SV: 1.4e-05 conc: 2.6e-03
# [Epoch 40/1000] Train SV: 1.8e-05 conc: 2.3e-03 | Val SV: 1.3e-05 conc: 3.1e-03
# [Epoch 41/1000] Train SV: 1.7e-05 conc: 2.5e-03 | Val SV: 1.3e-05 conc: 3.2e-03
# [Epoch 42/1000] Train SV: 1.7e-05 conc: 2.7e-03 | Val SV: 1.2e-05 conc: 3.0e-03
# [Epoch 43/1000] Train SV: 1.6e-05 conc: 2.8e-03 | Val SV: 1.3e-05 conc: 2.7e-03
# [Epoch 44/1000] Train SV: 1.7e-05 conc: 2.4e-03 | Val SV: 1.2e-05 conc: 2.6e-03
# [Epoch 45/1000] Train SV: 1.6e-05 conc: 2.0e-03 | Val SV: 1.2e-05 conc: 4.3e-03
# [Epoch 46/1000] Train SV: 1.6e-05 conc: 2.7e-03 | Val SV: 1.3e-05 conc: 3.3e-03
# [Epoch 47/1000] Train SV: 1.6e-05 conc: 2.3e-03 | Val SV: 1.2e-05 conc: 2.6e-03
# [Epoch 48/1000] Train SV: 1.5e-05 conc: 2.3e-03 | Val SV: 1.1e-05 conc: 4.1e-03
# [Epoch 49/1000] Train SV: 1.5e-05 conc: 2.8e-03 | Val SV: 1.1e-05 conc: 3.0e-03
# [Epoch 50/1000] Train SV: 1.5e-05 conc: 2.3e-03 | Val SV: 1.2e-05 conc: 4.0e-03
# [Epoch 51/1000] Train SV: 1.5e-05 conc: 2.0e-03 | Val SV: 1.1e-05 conc: 2.7e-03
# [Epoch 52/1000] Train SV: 1.4e-05 conc: 2.3e-03 | Val SV: 1.1e-05 conc: 3.0e-03
# [Epoch 53/1000] Train SV: 1.4e-05 conc: 2.0e-03 | Val SV: 1.1e-05 conc: 3.6e-03
# [Epoch 54/1000] Train SV: 1.4e-05 conc: 2.3e-03 | Val SV: 1.1e-05 conc: 2.5e-03
# [Epoch 55/1000] Train SV: 1.4e-05 conc: 2.3e-03 | Val SV: 1.1e-05 conc: 3.4e-03
# [Epoch 56/1000] Train SV: 1.4e-05 conc: 2.4e-03 | Val SV: 1.1e-05 conc: 4.1e-03
# [Epoch 57/1000] Train SV: 1.3e-05 conc: 1.9e-03 | Val SV: 1.0e-05 conc: 2.6e-03
# [Epoch 58/1000] Train SV: 1.3e-05 conc: 2.1e-03 | Val SV: 1.0e-05 conc: 3.0e-03
# [Epoch 59/1000] Train SV: 1.3e-05 conc: 2.1e-03 | Val SV: 1.0e-05 conc: 2.9e-03
# [Epoch 60/1000] Train SV: 1.2e-05 conc: 1.9e-03 | Val SV: 9.7e-06 conc: 2.7e-03
# [Epoch 61/1000] Train SV: 1.3e-05 conc: 2.3e-03 | Val SV: 1.0e-05 conc: 3.3e-03
# [Epoch 62/1000] Train SV: 1.3e-05 conc: 2.4e-03 | Val SV: 9.7e-06 conc: 3.4e-03
# [Epoch 63/1000] Train SV: 1.2e-05 conc: 2.2e-03 | Val SV: 9.4e-06 conc: 2.8e-03
# [Epoch 64/1000] Train SV: 1.2e-05 conc: 2.3e-03 | Val SV: 9.4e-06 conc: 2.5e-03
# [Epoch 65/1000] Train SV: 1.2e-05 conc: 2.1e-03 | Val SV: 9.5e-06 conc: 2.9e-03
# [Epoch 66/1000] Train SV: 1.4e-05 conc: 1.8e-03 | Val SV: 1.0e-05 conc: 3.1e-03
# [Epoch 67/1000] Train SV: 1.2e-05 conc: 1.8e-03 | Val SV: 9.2e-06 conc: 3.2e-03
# [Epoch 68/1000] Train SV: 1.2e-05 conc: 1.8e-03 | Val SV: 9.3e-06 conc: 2.9e-03
# [Epoch 69/1000] Train SV: 1.2e-05 conc: 1.7e-03 | Val SV: 9.3e-06 conc: 2.8e-03
# [Epoch 70/1000] Train SV: 1.2e-05 conc: 1.8e-03 | Val SV: 9.2e-06 conc: 2.8e-03
# [Epoch 71/1000] Train SV: 1.1e-05 conc: 2.1e-03 | Val SV: 8.6e-06 conc: 2.9e-03
# [Epoch 72/1000] Train SV: 1.1e-05 conc: 1.9e-03 | Val SV: 8.6e-06 conc: 3.0e-03
# [Epoch 73/1000] Train SV: 1.1e-05 conc: 2.4e-03 | Val SV: 8.9e-06 conc: 4.5e-03
# [Epoch 74/1000] Train SV: 1.1e-05 conc: 2.4e-03 | Val SV: 8.3e-06 conc: 3.5e-03
# [Epoch 75/1000] Train SV: 1.1e-05 conc: 1.9e-03 | Val SV: 8.4e-06 conc: 2.9e-03
# [Epoch 76/1000] Train SV: 1.1e-05 conc: 1.6e-03 | Val SV: 8.2e-06 conc: 2.8e-03
# [Epoch 77/1000] Train SV: 1.0e-05 conc: 1.9e-03 | Val SV: 8.3e-06 conc: 2.8e-03
# [Epoch 78/1000] Train SV: 1.1e-05 conc: 1.7e-03 | Val SV: 8.6e-06 conc: 3.1e-03
# [Epoch 79/1000] Train SV: 1.0e-05 conc: 1.7e-03 | Val SV: 8.0e-06 conc: 2.8e-03
# [Epoch 80/1000] Train SV: 1.0e-05 conc: 2.0e-03 | Val SV: 7.9e-06 conc: 3.1e-03
# [Epoch 81/1000] Train SV: 1.0e-05 conc: 2.2e-03 | Val SV: 8.0e-06 conc: 3.2e-03
# [Epoch 82/1000] Train SV: 9.8e-06 conc: 1.7e-03 | Val SV: 8.0e-06 conc: 2.8e-03
# [Epoch 83/1000] Train SV: 9.8e-06 conc: 1.8e-03 | Val SV: 7.7e-06 conc: 3.3e-03
# [Epoch 84/1000] Train SV: 9.6e-06 conc: 1.8e-03 | Val SV: 7.6e-06 conc: 2.7e-03
# [Epoch 85/1000] Train SV: 9.6e-06 conc: 1.7e-03 | Val SV: 7.6e-06 conc: 2.6e-03
# [Epoch 86/1000] Train SV: 9.4e-06 conc: 1.5e-03 | Val SV: 7.2e-06 conc: 2.8e-03
# [Epoch 87/1000] Train SV: 9.3e-06 conc: 1.7e-03 | Val SV: 7.3e-06 conc: 3.0e-03
# [Epoch 88/1000] Train SV: 9.3e-06 conc: 1.8e-03 | Val SV: 7.4e-06 conc: 2.7e-03
# Early stopping triggered. Restoring best weights.
# Model weights saved to 'model_name_2.weights.h5' and config saved to 'model_name_2.config.json'.

# %%
###############################################################################
# TEST
###############################################################################

# Predict OD in log scale
if val_array is not None:
    Pred, Ref = {}, {}
    for i in range(N_iter):
        model_name = 'model_name_'+str(int(i))
        model = MetabolicModel.load_model(model_name=model_name, verbose=False)
        pred_val_od, ref_val_od = predict_biomass_on_val_data(model, val_array, verbose=False)
        pred = np.log(ReLU(pred_val_od / ALPHA) + 1.0e-8)
        ref  = np.log(ReLU(ref_val_od / ALPHA)  + 1.0e-8)
        Pred[i] = np.asarray(pred)
        Ref[i]  = np.asarray(ref)
    Ref, Pred = np.asarray(list(Ref.values())), np.asarray(list(Pred.values()))
    ref, pred = np.mean(Ref, axis=0), np.mean(Pred, axis=0)
    ref_std, pred_std = np.std(Ref,axis=0), np.std(Pred, axis=0)
    similarity = 0
    # For each experiment, compute an error metric and annotate the plot.
    for i in range(ref.shape[0]):
        refi, predi = ref[i], pred[i]
        refi_std, predi_std = ref_std[i], pred_std[i]
        c = compute_curve_similarity(model.times, refi, predi)
        title = f'Experiment {i} Pred-True similarity: {c:.2f}'
        similarity += c
        plot_pred(title, model.times, refi, predi, ref_std=refi_std, pred_std=predi_std)
    print(f'Model: {model_name} Average Pred-True similarity = {similarity/len(pred_OD):.2f}')
# Out:
# Experiment 0 Pred-True similarity: 0.83
# Experiment 1 Pred-True similarity: 0.91
# Experiment 2 Pred-True similarity: 0.89
# Experiment 3 Pred-True similarity: 0.96
# Experiment 4 Pred-True similarity: 0.96
# Experiment 5 Pred-True similarity: 0.97
# Experiment 6 Pred-True similarity: 0.94
# Experiment 7 Pred-True similarity: 0.90
# Experiment 8 Pred-True similarity: 0.96
# Experiment 9 Pred-True similarity: 0.96
# Experiment 10 Pred-True similarity: 0.97
# Experiment 11 Pred-True similarity: 0.96
# Experiment 12 Pred-True similarity: 0.96
# Experiment 13 Pred-True similarity: 0.91
# Experiment 14 Pred-True similarity: 0.95
# Experiment 15 Pred-True similarity: 0.95
# Experiment 16 Pred-True similarity: 0.94
# Experiment 17 Pred-True similarity: 0.89
# Experiment 18 Pred-True similarity: 0.93
# Experiment 19 Pred-True similarity: 0.95
# Experiment 20 Pred-True similarity: 0.96
# Experiment 21 Pred-True similarity: 0.95
# Experiment 22 Pred-True similarity: 0.95
# Experiment 23 Pred-True similarity: 0.93
# Experiment 24 Pred-True similarity: 0.96
# Experiment 25 Pred-True similarity: 0.96
# Experiment 26 Pred-True similarity: 0.96
# Experiment 27 Pred-True similarity: 0.95
# Experiment 28 Pred-True similarity: 0.94
# Experiment 29 Pred-True similarity: 0.93
# Experiment 30 Pred-True similarity: 0.89
# Experiment 31 Pred-True similarity: 0.96
# Experiment 32 Pred-True similarity: 0.91
# Experiment 33 Pred-True similarity: 0.89
# Experiment 34 Pred-True similarity: 0.91
# Experiment 35 Pred-True similarity: 0.90
# Experiment 36 Pred-True similarity: 0.83
# Experiment 37 Pred-True similarity: 0.90
# Experiment 38 Pred-True similarity: 0.92
# Experiment 39 Pred-True similarity: 0.92
# Experiment 40 Pred-True similarity: 0.93
# Experiment 41 Pred-True similarity: 0.94
# Experiment 42 Pred-True similarity: 0.94
# Experiment 43 Pred-True similarity: 0.82
# Experiment 44 Pred-True similarity: 0.86
# Experiment 45 Pred-True similarity: 0.91
# Experiment 46 Pred-True similarity: 0.94
# Experiment 47 Pred-True similarity: 0.87
# Experiment 48 Pred-True similarity: 0.96
# Experiment 49 Pred-True similarity: 0.95
# Experiment 50 Pred-True similarity: 0.92
# Experiment 51 Pred-True similarity: 0.95
# Experiment 52 Pred-True similarity: 0.82
# Experiment 53 Pred-True similarity: 0.95
# Experiment 54 Pred-True similarity: 0.87
# Experiment 55 Pred-True similarity: 0.89
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 28
#      26     similarity += c
#      27     plot_pred(model.times, refi, predi, ref_std=refi_std, pred_std=predi_std)
# ---> 28 print(f'Model: {model_name} Average Pred-True similarity = {similarity/len(pred_OD):.2f}')
#
# NameError: name 'pred_OD' is not defined

# %% [markdown]
# Parameter search
#
# 100
# Model: OD_clean_10_1.0 Average Pred-True similarity = 0.90
#
# 500
# Model: OD_clean_10_1.0 Average Pred-True similarity = 0.92 weight = 0.0
#
# 500
# Model: OD_clean_10_1.0 Average Pred-True similarity = 0.90 weight = 1.0
#
# 500
# Model: OD_clean_10_1.0 Average Pred-True similarity = 0.90 weight = 0.1
#
# 500
# Model: OD_clean_10_1.0 Average Pred-True similarity = 0.88 weight drop = 0.5
#
# 500
# Model: OD_clean_10_1.0 Average Pred-True similarity = 0.92 weight drop = 0.5 decay = 0.5
#
# 1000
# Model: OD_clean_10_1.0 Average Pred-True similarity = 0.92 weight drop = 0.5 decay = 0.5
#
#                  500
#                  loss_weight_ng_v = 5e-1,
#                  loss_weight_drop_conc  = 1e-1,
#                  loss_weight_decay_conc = 5e-1,
#                  loss_weight_sv = 1e-3,
# Model: OD_clean_20_1.0 Average Pred-True similarity = 0.90
